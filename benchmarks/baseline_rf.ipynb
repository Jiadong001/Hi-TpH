# %%
import os
import random
import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import roc_auc_score, accuracy_score, matthews_corrcoef, f1_score, recall_score

seed = 42
def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)

# %% [markdown]
# ## 1. Prepare data
# ### 1.1. Read data

# %%
level = "1"
data_path = f"/data/lujd/TCRdata/benchmarks/level{level}/"
train_df = pd.read_csv(os.path.join(data_path,"train_data_fold{}.csv".format(0)))
valid_df = pd.read_csv(os.path.join(data_path,"valid_data_fold{}.csv".format(0)))
test_df = pd.read_csv(os.path.join(data_path,"test_data_fold{}.csv".format(0)))
tcr2candidates = np.load(os.path.join(data_path, "tcr2candidates_pools.npy"), allow_pickle=True).tolist()

# rename beta'/'ab' -> 'pos_tcr'
if 'beta' in train_df.columns:
    train_df.rename(columns={'beta':'pos_tcr'}, inplace=True)
    valid_df.rename(columns={'beta':'pos_tcr'}, inplace=True)
    test_df.rename(columns={'beta':'pos_tcr'}, inplace=True)
elif 'ab' in train_df.columns:
    train_df.rename(columns={'ab':'pos_tcr'}, inplace=True)
    valid_df.rename(columns={'ab':'pos_tcr'}, inplace=True)
    test_df.rename(columns={'ab':'pos_tcr'}, inplace=True)
elif 'tcr' in train_df.columns:
    train_df.rename(columns={'tcr':'pos_tcr'}, inplace=True)
    valid_df.rename(columns={'tcr':'pos_tcr'}, inplace=True)
    test_df.rename(columns={'tcr':'pos_tcr'}, inplace=True)
else:
    raise TypeError("Wrong data format!")

train_df.head(3)
# Out:
#          pep          pos_tcr  label
# 0  YPDKVFRSS  CASSLEVTSQETQYF      1
# 1  AFLLFLVLI  CASSFTGTLNYGYTF      1
# 2  FYLCFLAFL     CASSYVGNEQFF      1

# %% [markdown]
# ### 1.2. Select the same number of negative samples for each dataset

# %%
set_seed(seed)

def add_random_neg_samples(df, neg_tcr_candidates):
    df = df[df['label'] == 1]
    true_pep2tcr_mapping = df.groupby('pep')['pos_tcr'].unique().to_dict()

    new_rows = []
    for index, row in df.iterrows():
        pep = row['pep']
        features = row.drop('label')

        # sample negative tcr
        binding_tcrs = set(true_pep2tcr_mapping.get(pep))
        neg_tcr = random.choice(neg_tcr_candidates)
        while neg_tcr in binding_tcrs:
            neg_tcr = random.choice(neg_tcr_candidates)
        # print(neg_tcr)

        new_row = {'neg_tcr': neg_tcr}
        new_row.update(features)
        new_rows.append(new_row)

    return pd.DataFrame(new_rows)

train_df = add_random_neg_samples(train_df, tcr2candidates)
valid_df = add_random_neg_samples(valid_df, tcr2candidates)

test_dfs = []
for _ in range(5):
    # test_df = add_random_neg_samples(test_df, tcr2candidates)
    test_dfs.append(add_random_neg_samples(test_df, tcr2candidates))

train_df.head(3)
# Out:
#              neg_tcr        pep          pos_tcr
# 0  CASSVGASGGRYNEQFF  YPDKVFRSS  CASSLEVTSQETQYF
# 1       ASSFGGIGNEQF  AFLLFLVLI  CASSFTGTLNYGYTF
# 2      ASSLEGEYAQPQH  FYLCFLAFL     CASSYVGNEQFF

# %%
test_dfs[0].head(3)
# Out:
#             neg_tcr         pep           pos_tcr
# 0  CASSQDPWASGNEQYF   KLGGALQAK        SAWGIQDTQY
# 1        ASVVVGNEQF   YLCFLAFLL   CSADGLAGYQETQYF
# 2   ASSPGLGGASTDTQY  FYLCFLAFLL  CASSEEGGVPNYGYTF

# %%
test_dfs[1].head(3)
# Out:
#                neg_tcr         pep           pos_tcr
# 0       CASSSSGLTYEQYF   KLGGALQAK        SAWGIQDTQY
# 1  CASSHPQGVTSRSGNTIYF   YLCFLAFLL   CSADGLAGYQETQYF
# 2        ASSGGITGEETQY  FYLCFLAFLL  CASSEEGGVPNYGYTF

# %% [markdown]
# ## 2. Data processing
#
# ### 2.1. pad then cat
#
# - Uniform input length

# %%
if level in ['1']:
    pep_max_len = 15
    tcr_max_len_single = 19
elif level in ['2a', '2a_basic', '2b', '2b_basic', '3', '3_basic']:
    pep_max_len = 10
    tcr_max_len_single = 19
elif level in ['4', '4_basic']:
    pep_max_len = 10
    tcr_max_len_single = 121
print(f'level-{level}: pep_max_len={pep_max_len}, tcr_max_len(single chain)={tcr_max_len_single}')

train_df['pep'] = train_df['pep'].apply(lambda pep: pep.ljust(pep_max_len, 'X'))
train_df['pos_tcr'] = train_df['pos_tcr'].apply(
        lambda tcr: ''.join([s.ljust(tcr_max_len_single, 'X') for s in tcr.split('/')]))
train_df['neg_tcr'] = train_df['neg_tcr'].apply(
        lambda tcr: ''.join([s.ljust(tcr_max_len_single, 'X') for s in tcr.split('/')]))
print(train_df['pep'].str.len().unique(),
      train_df['pos_tcr'].str.len().unique(), 
      train_df['neg_tcr'].str.len().unique())

valid_df['pep'] = valid_df['pep'].apply(lambda pep: pep.ljust(pep_max_len, 'X'))
valid_df['pos_tcr'] = valid_df['pos_tcr'].apply(
        lambda tcr: ''.join([s.ljust(tcr_max_len_single, 'X') for s in tcr.split('/')]))
valid_df['neg_tcr'] = valid_df['neg_tcr'].apply(
        lambda tcr: ''.join([s.ljust(tcr_max_len_single, 'X') for s in tcr.split('/')]))
print(valid_df['pep'].str.len().unique(),
      valid_df['pos_tcr'].str.len().unique(), 
      valid_df['neg_tcr'].str.len().unique())

for df in test_dfs: 
    df['pep'] = df['pep'].apply(lambda pep: pep.ljust(pep_max_len, 'X'))
    df['pos_tcr'] = df['pos_tcr'].apply(
        lambda tcr: ''.join([s.ljust(tcr_max_len_single, 'X') for s in tcr.split('/')]))
    df['neg_tcr'] = df['neg_tcr'].apply(
        lambda tcr: ''.join([s.ljust(tcr_max_len_single, 'X') for s in tcr.split('/')]))
    print(df['pep'].str.len().unique(),
        df['pos_tcr'].str.len().unique(), 
        df['neg_tcr'].str.len().unique())
# Out:
# level-1: pep_max_len=15, tcr_max_len(single chain)=19
# [15] [19] [19]
# [15] [19] [19]
# [15] [19] [19]
# [15] [19] [19]
# [15] [19] [19]
# [15] [19] [19]
# [15] [19] [19]

# %%
test_dfs[1].head(3)
# Out:
#                neg_tcr              pep              pos_tcr
# 0  CASSSSGLTYEQYFXXXXX  KLGGALQAKXXXXXX  SAWGIQDTQYXXXXXXXXX
# 1  CASSHPQGVTSRSGNTIYF  YLCFLAFLLXXXXXX  CSADGLAGYQETQYFXXXX
# 2  ASSGGITGEETQYXXXXXX  FYLCFLAFLLXXXXX  CASSEEGGVPNYGYTFXXX

# %%
def build_full_df(df):
    if 'hla' in df.columns:
        pos_df = df[['pep', 'hla', 'pos_tcr']]
        neg_df = df[['pep', 'hla', 'neg_tcr']]
    else:
        pos_df = df[['pep', 'pos_tcr']]
        neg_df = df[['pep', 'neg_tcr']]
    pos_df.rename(columns={'pos_tcr':'tcr'}, inplace=True)
    print(len(pos_df))
    pos_df['label'] = 1
    neg_df.rename(columns={'neg_tcr':'tcr'}, inplace=True)
    print(len(neg_df))
    neg_df.loc[:, 'label'] = 0
    return pd.concat((pos_df, neg_df), axis=0).reset_index(drop=True)

train_full_df = build_full_df(train_df)
valid_full_df = build_full_df(valid_df)

test_full_dfs = []
for df in test_dfs: 
    test_full_dfs.append(build_full_df(df))
# Out:
# 548026
# 548026
# 68503
# 68503
# 68504
# 68504
# 68504
# 68504
# /tmp/ipykernel_278104/701188312.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pos_df.rename(columns={'pos_tcr':'tcr'}, inplace=True)
# /tmp/ipykernel_278104/701188312.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   neg_df.rename(columns={'neg_tcr':'tcr'}, inplace=True)
# /tmp/ipykernel_278104/701188312.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pos_df.rename(columns={'pos_tcr':'tcr'}, inplace=True)
# /tmp/ipykernel_278104/701188312.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   neg_df.rename(columns={'neg_tcr':'tcr'}, inplace=True)
# /tmp/ipykernel_278104/701188312.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pos_df.rename(columns={'pos_tcr':'tcr'}, inplace=True)
# /tmp/ipykernel_278104/701188312.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   neg_df.rename(columns={'neg_tcr':'tcr'}, inplace=True)
# /tmp/ipykernel_278104/701188312.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pos_df.rename(columns={'pos_tcr':'tcr'}, inplace=True)
# /tmp/ipykernel_278104/701188312.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   neg_df.rename(columns={'neg_tcr':'tcr'}, inplace=True)
# /tmp/ipykernel_278104/701188312.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pos_df.rename(columns={'pos_tcr':'tcr'}, inplace=True)
# /tmp/ipykernel_278104/701188312.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   neg_df.rename(columns={'neg_tcr':'tcr'}, inplace=True)
# /tmp/ipykernel_278104/701188312.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pos_df.rename(columns={'pos_tcr':'tcr'}, inplace=True)
# /tmp/ipykernel_278104/701188312.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   neg_df.rename(columns={'neg_tcr':'tcr'}, inplace=True)
# /tmp/ipykernel_278104/701188312.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pos_df.rename(columns={'pos_tcr':'tcr'}, inplace=True)
# /tmp/ipykernel_278104/701188312.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   neg_df.rename(columns={'neg_tcr':'tcr'}, inplace=True)
# 68504
# 68504
# 68504
# 68504
# 68504
# 68504

# %%
if 'hla' in train_full_df.columns:
    train_full_df['cat_seq'] = train_full_df['tcr'] + train_full_df['pep'] + train_full_df['hla']
    valid_full_df['cat_seq'] = valid_full_df['tcr'] + valid_full_df['pep'] + valid_full_df['hla']
    for df in test_full_dfs: 
        df['cat_seq'] = df['tcr'] + df['pep'] + df['hla']
else:
    train_full_df['cat_seq'] = train_full_df['tcr'] + train_full_df['pep']
    valid_full_df['cat_seq'] = valid_full_df['tcr'] + valid_full_df['pep']
    for df in test_full_dfs: 
        df['cat_seq'] = df['tcr'] + df['pep']

train_full_df.head(3)
# Out:
#                pep                  tcr  label  \
# 0  YPDKVFRSSXXXXXX  CASSLEVTSQETQYFXXXX      1
# 1  AFLLFLVLIXXXXXX  CASSFTGTLNYGYTFXXXX      1
# 2  FYLCFLAFLXXXXXX  CASSYVGNEQFFXXXXXXX      1
#
#                               cat_seq
# 0  CASSLEVTSQETQYFXXXXYPDKVFRSSXXXXXX
# 1  CASSFTGTLNYGYTFXXXXAFLLFLVLIXXXXXX
# 2  CASSYVGNEQFFXXXXXXXFYLCFLAFLXXXXXX

# %% [markdown]
# ### 2.2. Shuffle Training data (Optional)

# %%
SHUFFLE_TRAIN = True
if SHUFFLE_TRAIN:
    train_full_df = train_full_df.sample(frac=1, random_state=seed).reset_index(drop=True)

train_full_df.head(3)
# Out:
#                pep                  tcr  label  \
# 0  LIDFYLCFLXXXXXX  ASSELGEAFXXXXXXXXXX      0
# 1  SLIDFYLCFLXXXXX  CASSLPLSYEQYFXXXXXX      1
# 2  MIELSLIDFYXXXXX  CASSSYQGAYEQYFXXXXX      0
#
#                               cat_seq
# 0  ASSELGEAFXXXXXXXXXXLIDFYLCFLXXXXXX
# 1  CASSLPLSYEQYFXXXXXXSLIDFYLCFLXXXXX
# 2  CASSSYQGAYEQYFXXXXXMIELSLIDFYXXXXX

# %% [markdown]
# ## 3. Feature extraction
#
# ### 3.1. Encoding an amino acid to a numeric vetcor
#
# - Onehot encoding

# %%
encoder = OneHotEncoder(categories='auto', sparse_output=False, handle_unknown='ignore')

# train
train_features = train_full_df['cat_seq'].values
train_labels = train_full_df['label'].values

train_features = [[s for s in seq] for seq in train_features]
train_features = np.array(train_features).reshape(-1, 1)            # [len(df)*seq_len, 1]

train_features = encoder.fit_transform(train_features)
train_features = train_features.reshape((len(train_full_df),-1))    # [len(df), seq_len]
print(train_features.shape, train_labels.shape)

print(encoder.categories_ )        # O
# Out:
# (1096052, 748) (1096052,)
# [array(['A', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'K', 'L', 'M', 'N', 'O',
#        'P', 'Q', 'R', 'S', 'T', 'V', 'W', 'X', 'Y'], dtype='<U1')]

# %%
# valid
valid_features = valid_full_df['cat_seq'].values
valid_labels = valid_full_df['label'].values

valid_features = [[s for s in seq] for seq in valid_features]
valid_features = np.array(valid_features).reshape(-1, 1)            # [len(df)*seq_len, 1]

valid_features = encoder.transform(valid_features)
valid_features = valid_features.reshape((len(valid_full_df),-1))    # [len(df), seq_len]
print(valid_features.shape, valid_labels.shape)
# Out:
# (137006, 748) (137006,)

# %%
# test
test_features_list = []
test_labels_list = []
for test_full_df in test_full_dfs:
    test_features = test_full_df['cat_seq'].values
    test_labels = test_full_df['label'].values

    test_features = [[s for s in seq] for seq in test_features]
    test_features = np.array(test_features).reshape(-1, 1)            # [len(df)*seq_len, 1]

    test_features = encoder.transform(test_features)
    test_features = test_features.reshape((len(test_full_df),-1))    # [len(df), seq_len]
    print(test_features.shape, test_labels.shape)

    test_features_list.append(test_features)
    test_labels_list.append(test_labels)
# Out:
# (137008, 748) (137008,)
# (137008, 748) (137008,)
# (137008, 748) (137008,)
# (137008, 748) (137008,)
# (137008, 748) (137008,)

# %% [markdown]
# ### 3.2. Scaler (Optional)

# %%
SCALE = False   # no need
if SCALE:
    scaler = StandardScaler()
    train_features = scaler.fit_transform(train_features)
    valid_features = scaler.transform(valid_features)
    for i in range(len(test_features_list)):
        test_features_list[i] = scaler.transform(test_features_list[i])

# %% [markdown]
# ## 4. Model training
# ### 4.1. Prepare metrics

# %%
def cal_metrics(labels, y_pred, y_prob=[]):     # y_pred: label, y_prob: probability
    if len(y_prob) == 0:
        auc = roc_auc_score(labels, y_pred)     # same as acc
    else:
        assert len(labels) == len(y_prob)
        auc = roc_auc_score(labels, y_prob)
    acc = accuracy_score(labels, y_pred)
    mcc = matthews_corrcoef(labels, y_pred)
    f1 = f1_score(labels, y_pred)
    recall = recall_score(labels, y_pred)

    print("Validation Performance:")
    print(f"- AUC: {auc:.6f} | ACC: {acc:.6f} | MCC: {mcc:.6f} | F1:  {f1:.6f} | Recall:  {recall:.6f}")

    return (auc, acc, mcc, f1), recall

# %% [markdown]
# ### 4.2. RandomForest
#
# #### 4.2.1. Train RandomForest
# <!-- - GridSeach using train data -->
# - Use GridSeach for important hyperparameters

# %%
rf_model = RandomForestClassifier(n_estimators=300,     # 100, 200, 300
                                  # max_features=20, 
                                  # max_depth=10,       # None, 10, 20
                                  random_state=seed, 
                                  n_jobs=-1,
                                  bootstrap=True)

print(">>> Training starts.")
rf_model.fit(train_features, train_labels)
print(">>> Training ends.")

print(">>> Validating starts.")
y_valid_pred = rf_model.predict(valid_features)
y_valid_prob = rf_model.predict_proba(valid_features)[:, 1]
metrics, recall = cal_metrics(valid_labels, y_valid_pred, y_valid_prob)
print(f"- Average (AUC, ACC, MCC, F1): {sum(metrics)/len(metrics):6f}")
print(">>> Validating ends.")
# Out:
# >>> Training starts.
# >>> Training ends.
# >>> Validating starts.
# Validation Performance:
# - AUC: 0.819835 | ACC: 0.729596 | MCC: 0.465638 | F1:  0.750298 | Recall:  0.812505
# - Average (AUC, ACC, MCC, F1): 0.691342
# >>> Validating ends.

# %% [markdown]
# ||1|2a|2a_basic|2b|2b_basic|3|3_basic|4|4_basic|
# |:-:|:-:|:-:|:-:|:-:|:-:|:-:|:-:|:-:|:-:|
# |n_estimators|300|100|100|100|100|300|300|100|100|
# |max_depth|None|20|20|10|10|10|10|10|10|
#
# - Empty means default
#
# - use max_depth: 0.68->0.72
#
# - max_features: no use

# %% [markdown]
# #### 4.2.2. Test RandomForest

# %%
aucs, accs, mccs, f1s, recalls = [], [], [], [], []
for test_features, test_labels in zip(test_features_list, test_labels_list):
    y_test_pred = rf_model.predict(test_features)               # threshold=0.5 (>0.5: 1)
    y_test_prob = rf_model.predict_proba(test_features)[:, 1]

    test_metrics, test_recall = cal_metrics(test_labels, y_test_pred, y_test_prob)
    print(f"- Average (AUC, ACC, MCC, F1): {sum(test_metrics)/len(test_metrics):6f}")
    
    aucs.append(test_metrics[0])
    accs.append(test_metrics[1])
    mccs.append(test_metrics[2])
    f1s.append(test_metrics[3])
    recalls.append(test_recall)

print("Average on 5 test sets: ")
print(f"- AUC: {sum(aucs)/len(aucs):.6f} | ACC: {sum(accs)/len(accs):.6f} | MCC: {sum(mccs)/len(mccs):.6f} | F1:  {sum(f1s)/len(f1s):.6f} | Recall:  {sum(recalls)/len(recalls):.6f}")
# Out:
# Validation Performance:
# - AUC: 0.820690 | ACC: 0.731103 | MCC: 0.468523 | F1:  0.751442 | Recall:  0.812931
# - Average (AUC, ACC, MCC, F1): 0.692940
# Validation Performance:
# - AUC: 0.819538 | ACC: 0.730081 | MCC: 0.466613 | F1:  0.750733 | Recall:  0.812931
# - Average (AUC, ACC, MCC, F1): 0.691742
# Validation Performance:
# - AUC: 0.821225 | ACC: 0.731249 | MCC: 0.468796 | F1:  0.751544 | Recall:  0.812931
# - Average (AUC, ACC, MCC, F1): 0.693203
# Validation Performance:
# - AUC: 0.819985 | ACC: 0.731125 | MCC: 0.468564 | F1:  0.751457 | Recall:  0.812931
# - Average (AUC, ACC, MCC, F1): 0.692783
# Validation Performance:
# - AUC: 0.819155 | ACC: 0.728804 | MCC: 0.464226 | F1:  0.749849 | Recall:  0.812931
# - Average (AUC, ACC, MCC, F1): 0.690509
# Average on 5 test sets:
# - AUC: 0.820119 | ACC: 0.730473 | MCC: 0.467345 | F1:  0.751005 | Recall:  0.812931

# %% [markdown]
# ### 4.3. (Optional) XGBoost
#
# #### 4.3.1. Train XGBoost

# %%
import xgboost as xgb

parameters = {'objective': 'binary:logistic', 
              'eval_metric': 'auc', 
              'eta': 0.3,       # learning_rate
              'seed': seed}
num_round = 2000

dtrain = xgb.DMatrix(train_features, label=train_labels)
dvalid = xgb.DMatrix(valid_features, label=valid_labels)
xgb_model = xgb.train(parameters, 
               dtrain, 
               num_boost_round=num_round,
               evals=[(dtrain,'train'), (dvalid,'val')],
               early_stopping_rounds=20,        # If you don't stop early, yo u will overfit. 20 is a more appropriate value when eta = 0.3.
               verbose_eval=True
               )
# Out:
# [0]	train-auc:0.67385	val-auc:0.66914
# [1]	train-auc:0.67645	val-auc:0.67251
# [2]	train-auc:0.68506	val-auc:0.67935
# [3]	train-auc:0.68710	val-auc:0.68118
# [4]	train-auc:0.69205	val-auc:0.68533
# [5]	train-auc:0.69217	val-auc:0.68552
# [6]	train-auc:0.69578	val-auc:0.68895
# [7]	train-auc:0.69794	val-auc:0.69121
# [8]	train-auc:0.69836	val-auc:0.69173
# [9]	train-auc:0.69895	val-auc:0.69229
# [10]	train-auc:0.70201	val-auc:0.69514
# [11]	train-auc:0.70552	val-auc:0.69834
# [12]	train-auc:0.70591	val-auc:0.69868
# [13]	train-auc:0.70802	val-auc:0.70064
# [14]	train-auc:0.70912	val-auc:0.70142
# [15]	train-auc:0.71065	val-auc:0.70274
# [16]	train-auc:0.71185	val-auc:0.70384
# [17]	train-auc:0.71450	val-auc:0.70601
# [18]	train-auc:0.71698	val-auc:0.70814
# [19]	train-auc:0.71864	val-auc:0.70943
# [20]	train-auc:0.71951	val-auc:0.70973
# [21]	train-auc:0.72043	val-auc:0.71061
# [22]	train-auc:0.72102	val-auc:0.71132
# [23]	train-auc:0.72186	val-auc:0.71183
# [24]	train-auc:0.72248	val-auc:0.71235
# [25]	train-auc:0.72329	val-auc:0.71266
# [26]	train-auc:0.72342	val-auc:0.71275
# [27]	train-auc:0.72460	val-auc:0.71415
# [28]	train-auc:0.72497	val-auc:0.71441
# [29]	train-auc:0.72624	val-auc:0.71572
# [30]	train-auc:0.72719	val-auc:0.71636
# [31]	train-auc:0.72798	val-auc:0.71707
# [32]	train-auc:0.72828	val-auc:0.71725
# [33]	train-auc:0.72853	val-auc:0.71740
# [34]	train-auc:0.72929	val-auc:0.71806
# [35]	train-auc:0.72956	val-auc:0.71833
# [36]	train-auc:0.73024	val-auc:0.71900
# [37]	train-auc:0.73038	val-auc:0.71904
# [38]	train-auc:0.73117	val-auc:0.71975
# [39]	train-auc:0.73170	val-auc:0.72017
# [40]	train-auc:0.73219	val-auc:0.72059
# [41]	train-auc:0.73361	val-auc:0.72163
# [42]	train-auc:0.73502	val-auc:0.72286
# [43]	train-auc:0.73526	val-auc:0.72312
# [44]	train-auc:0.73590	val-auc:0.72360
# [45]	train-auc:0.73617	val-auc:0.72382
# [46]	train-auc:0.73640	val-auc:0.72409
# [47]	train-auc:0.73707	val-auc:0.72459
# [48]	train-auc:0.73736	val-auc:0.72470
# [49]	train-auc:0.73762	val-auc:0.72480
# [50]	train-auc:0.73830	val-auc:0.72542
# [51]	train-auc:0.73854	val-auc:0.72549
# [52]	train-auc:0.73872	val-auc:0.72561
# [53]	train-auc:0.73941	val-auc:0.72641
# [54]	train-auc:0.73972	val-auc:0.72648
# [55]	train-auc:0.74018	val-auc:0.72692
# [56]	train-auc:0.74120	val-auc:0.72776
# [57]	train-auc:0.74165	val-auc:0.72817
# [58]	train-auc:0.74228	val-auc:0.72884
# [59]	train-auc:0.74327	val-auc:0.72962
# [60]	train-auc:0.74349	val-auc:0.72977
# [61]	train-auc:0.74362	val-auc:0.72989
# [62]	train-auc:0.74372	val-auc:0.72990
# [63]	train-auc:0.74437	val-auc:0.73039
# [64]	train-auc:0.74446	val-auc:0.73046
# [65]	train-auc:0.74486	val-auc:0.73074
# [66]	train-auc:0.74539	val-auc:0.73124
# [67]	train-auc:0.74613	val-auc:0.73184
# [68]	train-auc:0.74644	val-auc:0.73211
# [69]	train-auc:0.74663	val-auc:0.73215
# [70]	train-auc:0.74691	val-auc:0.73230
# [71]	train-auc:0.74728	val-auc:0.73253
# [72]	train-auc:0.74763	val-auc:0.73273
# [73]	train-auc:0.74862	val-auc:0.73343
# [74]	train-auc:0.74949	val-auc:0.73420
# [75]	train-auc:0.75027	val-auc:0.73498
# [76]	train-auc:0.75101	val-auc:0.73541
# [77]	train-auc:0.75129	val-auc:0.73556
# [78]	train-auc:0.75146	val-auc:0.73566
# [79]	train-auc:0.75150	val-auc:0.73566
# [80]	train-auc:0.75182	val-auc:0.73588
# [81]	train-auc:0.75233	val-auc:0.73623
# [82]	train-auc:0.75266	val-auc:0.73654
# [83]	train-auc:0.75309	val-auc:0.73689
# [84]	train-auc:0.75346	val-auc:0.73716
# [85]	train-auc:0.75412	val-auc:0.73772
# [86]	train-auc:0.75439	val-auc:0.73790
# [87]	train-auc:0.75468	val-auc:0.73808
# [88]	train-auc:0.75478	val-auc:0.73810
# [89]	train-auc:0.75507	val-auc:0.73832
# [90]	train-auc:0.75514	val-auc:0.73837
# [91]	train-auc:0.75538	val-auc:0.73847
# [92]	train-auc:0.75564	val-auc:0.73865
# [93]	train-auc:0.75590	val-auc:0.73883
# [94]	train-auc:0.75617	val-auc:0.73907
# [95]	train-auc:0.75651	val-auc:0.73924
# [96]	train-auc:0.75685	val-auc:0.73953
# [97]	train-auc:0.75694	val-auc:0.73951
# [98]	train-auc:0.75704	val-auc:0.73961
# [99]	train-auc:0.75716	val-auc:0.73964
# [100]	train-auc:0.75749	val-auc:0.73983
# [101]	train-auc:0.75755	val-auc:0.73984
# [102]	train-auc:0.75777	val-auc:0.73995
# [103]	train-auc:0.75787	val-auc:0.74005
# [104]	train-auc:0.75829	val-auc:0.74037
# [105]	train-auc:0.75843	val-auc:0.74041
# [106]	train-auc:0.75859	val-auc:0.74050
# [107]	train-auc:0.75910	val-auc:0.74094
# [108]	train-auc:0.75939	val-auc:0.74121
# [109]	train-auc:0.75958	val-auc:0.74128
# [110]	train-auc:0.75980	val-auc:0.74139
# [111]	train-auc:0.76008	val-auc:0.74164
# [112]	train-auc:0.76047	val-auc:0.74210
# [113]	train-auc:0.76087	val-auc:0.74239
# [114]	train-auc:0.76101	val-auc:0.74251
# [115]	train-auc:0.76119	val-auc:0.74253
# [116]	train-auc:0.76121	val-auc:0.74253
# [117]	train-auc:0.76131	val-auc:0.74255
# [118]	train-auc:0.76194	val-auc:0.74311
# [119]	train-auc:0.76208	val-auc:0.74324
# [120]	train-auc:0.76239	val-auc:0.74346
# [121]	train-auc:0.76268	val-auc:0.74367
# [122]	train-auc:0.76287	val-auc:0.74369
# [123]	train-auc:0.76307	val-auc:0.74380
# [124]	train-auc:0.76367	val-auc:0.74436
# [125]	train-auc:0.76398	val-auc:0.74449
# [126]	train-auc:0.76423	val-auc:0.74467
# [127]	train-auc:0.76450	val-auc:0.74492
# [128]	train-auc:0.76462	val-auc:0.74502
# [129]	train-auc:0.76490	val-auc:0.74529
# [130]	train-auc:0.76511	val-auc:0.74548
# [131]	train-auc:0.76541	val-auc:0.74570
# [132]	train-auc:0.76562	val-auc:0.74581
# [133]	train-auc:0.76594	val-auc:0.74611
# [134]	train-auc:0.76665	val-auc:0.74674
# [135]	train-auc:0.76695	val-auc:0.74691
# [136]	train-auc:0.76726	val-auc:0.74710
# [137]	train-auc:0.76747	val-auc:0.74722
# [138]	train-auc:0.76761	val-auc:0.74728
# [139]	train-auc:0.76766	val-auc:0.74734
# [140]	train-auc:0.76779	val-auc:0.74734
# [141]	train-auc:0.76782	val-auc:0.74735
# [142]	train-auc:0.76804	val-auc:0.74755
# [143]	train-auc:0.76823	val-auc:0.74765
# [144]	train-auc:0.76828	val-auc:0.74770
# [145]	train-auc:0.76851	val-auc:0.74786
# [146]	train-auc:0.76874	val-auc:0.74810
# [147]	train-auc:0.76879	val-auc:0.74810
# [148]	train-auc:0.76897	val-auc:0.74815
# [149]	train-auc:0.76920	val-auc:0.74828
# [150]	train-auc:0.76935	val-auc:0.74844
# [151]	train-auc:0.76960	val-auc:0.74864
# [152]	train-auc:0.76980	val-auc:0.74870
# [153]	train-auc:0.77005	val-auc:0.74894
# [154]	train-auc:0.77029	val-auc:0.74904
# [155]	train-auc:0.77066	val-auc:0.74929
# [156]	train-auc:0.77094	val-auc:0.74948
# [157]	train-auc:0.77134	val-auc:0.74977
# [158]	train-auc:0.77167	val-auc:0.75011
# [159]	train-auc:0.77184	val-auc:0.75022
# [160]	train-auc:0.77210	val-auc:0.75043
# [161]	train-auc:0.77238	val-auc:0.75060
# [162]	train-auc:0.77248	val-auc:0.75062
# [163]	train-auc:0.77263	val-auc:0.75074
# [164]	train-auc:0.77272	val-auc:0.75077
# [165]	train-auc:0.77280	val-auc:0.75080
# [166]	train-auc:0.77290	val-auc:0.75090
# [167]	train-auc:0.77315	val-auc:0.75101
# [168]	train-auc:0.77337	val-auc:0.75122
# [169]	train-auc:0.77346	val-auc:0.75122
# [170]	train-auc:0.77365	val-auc:0.75129
# [171]	train-auc:0.77368	val-auc:0.75129
# [172]	train-auc:0.77395	val-auc:0.75160
# [173]	train-auc:0.77435	val-auc:0.75195
# [174]	train-auc:0.77460	val-auc:0.75213
# [175]	train-auc:0.77478	val-auc:0.75224
# [176]	train-auc:0.77504	val-auc:0.75240
# [177]	train-auc:0.77532	val-auc:0.75254
# [178]	train-auc:0.77555	val-auc:0.75261
# [179]	train-auc:0.77593	val-auc:0.75281
# [180]	train-auc:0.77637	val-auc:0.75315
# [181]	train-auc:0.77658	val-auc:0.75327
# [182]	train-auc:0.77677	val-auc:0.75341
# [183]	train-auc:0.77699	val-auc:0.75359
# [184]	train-auc:0.77713	val-auc:0.75376
# [185]	train-auc:0.77725	val-auc:0.75388
# [186]	train-auc:0.77737	val-auc:0.75395
# [187]	train-auc:0.77747	val-auc:0.75401
# [188]	train-auc:0.77768	val-auc:0.75410
# [189]	train-auc:0.77782	val-auc:0.75418
# [190]	train-auc:0.77797	val-auc:0.75430
# [191]	train-auc:0.77820	val-auc:0.75437
# [192]	train-auc:0.77837	val-auc:0.75449
# [193]	train-auc:0.77845	val-auc:0.75452
# [194]	train-auc:0.77867	val-auc:0.75474
# [195]	train-auc:0.77877	val-auc:0.75482
# [196]	train-auc:0.77878	val-auc:0.75482
# [197]	train-auc:0.77896	val-auc:0.75488
# [198]	train-auc:0.77908	val-auc:0.75493
# [199]	train-auc:0.77935	val-auc:0.75508
# [200]	train-auc:0.77960	val-auc:0.75527
# [201]	train-auc:0.77970	val-auc:0.75529
# [202]	train-auc:0.77978	val-auc:0.75529
# [203]	train-auc:0.77987	val-auc:0.75537
# [204]	train-auc:0.78017	val-auc:0.75548
# [205]	train-auc:0.78041	val-auc:0.75565
# [206]	train-auc:0.78058	val-auc:0.75562
# [207]	train-auc:0.78084	val-auc:0.75574
# [208]	train-auc:0.78096	val-auc:0.75581
# [209]	train-auc:0.78098	val-auc:0.75581
# [210]	train-auc:0.78101	val-auc:0.75584
# [211]	train-auc:0.78113	val-auc:0.75591
# [212]	train-auc:0.78129	val-auc:0.75594
# [213]	train-auc:0.78142	val-auc:0.75606
# [214]	train-auc:0.78155	val-auc:0.75617
# [215]	train-auc:0.78166	val-auc:0.75628
# [216]	train-auc:0.78180	val-auc:0.75633
# [217]	train-auc:0.78187	val-auc:0.75635
# [218]	train-auc:0.78209	val-auc:0.75640
# [219]	train-auc:0.78213	val-auc:0.75642
# [220]	train-auc:0.78226	val-auc:0.75645
# [221]	train-auc:0.78242	val-auc:0.75652
# [222]	train-auc:0.78251	val-auc:0.75657
# [223]	train-auc:0.78260	val-auc:0.75660
# [224]	train-auc:0.78276	val-auc:0.75658
# [225]	train-auc:0.78298	val-auc:0.75679
# [226]	train-auc:0.78309	val-auc:0.75684
# [227]	train-auc:0.78329	val-auc:0.75691
# [228]	train-auc:0.78351	val-auc:0.75703
# [229]	train-auc:0.78370	val-auc:0.75717
# [230]	train-auc:0.78404	val-auc:0.75736
# [231]	train-auc:0.78428	val-auc:0.75752
# [232]	train-auc:0.78438	val-auc:0.75751
# [233]	train-auc:0.78459	val-auc:0.75760
# [234]	train-auc:0.78479	val-auc:0.75773
# [235]	train-auc:0.78501	val-auc:0.75788
# [236]	train-auc:0.78510	val-auc:0.75788
# [237]	train-auc:0.78515	val-auc:0.75794
# [238]	train-auc:0.78538	val-auc:0.75808
# [239]	train-auc:0.78554	val-auc:0.75821
# [240]	train-auc:0.78576	val-auc:0.75844
# [241]	train-auc:0.78591	val-auc:0.75856
# [242]	train-auc:0.78607	val-auc:0.75866
# [243]	train-auc:0.78635	val-auc:0.75883
# [244]	train-auc:0.78656	val-auc:0.75895
# [245]	train-auc:0.78680	val-auc:0.75900
# [246]	train-auc:0.78706	val-auc:0.75911
# [247]	train-auc:0.78723	val-auc:0.75928
# [248]	train-auc:0.78743	val-auc:0.75937
# [249]	train-auc:0.78754	val-auc:0.75949
# [250]	train-auc:0.78764	val-auc:0.75955
# [251]	train-auc:0.78769	val-auc:0.75960
# [252]	train-auc:0.78790	val-auc:0.75964
# [253]	train-auc:0.78807	val-auc:0.75977
# [254]	train-auc:0.78825	val-auc:0.75979
# [255]	train-auc:0.78841	val-auc:0.75980
# [256]	train-auc:0.78849	val-auc:0.75981
# [257]	train-auc:0.78859	val-auc:0.75988
# [258]	train-auc:0.78878	val-auc:0.75996
# [259]	train-auc:0.78890	val-auc:0.75999
# [260]	train-auc:0.78899	val-auc:0.76003
# [261]	train-auc:0.78908	val-auc:0.76007
# [262]	train-auc:0.78915	val-auc:0.76012
# [263]	train-auc:0.78926	val-auc:0.76013
# [264]	train-auc:0.78942	val-auc:0.76027
# [265]	train-auc:0.78950	val-auc:0.76027
# [266]	train-auc:0.78978	val-auc:0.76040
# [267]	train-auc:0.78994	val-auc:0.76045
# [268]	train-auc:0.79016	val-auc:0.76067
# [269]	train-auc:0.79029	val-auc:0.76074
# [270]	train-auc:0.79032	val-auc:0.76077
# [271]	train-auc:0.79045	val-auc:0.76072
# [272]	train-auc:0.79047	val-auc:0.76071
# [273]	train-auc:0.79065	val-auc:0.76082
# [274]	train-auc:0.79069	val-auc:0.76083
# [275]	train-auc:0.79076	val-auc:0.76090
# [276]	train-auc:0.79096	val-auc:0.76097
# [277]	train-auc:0.79122	val-auc:0.76113
# [278]	train-auc:0.79140	val-auc:0.76120
# [279]	train-auc:0.79163	val-auc:0.76134
# [280]	train-auc:0.79188	val-auc:0.76157
# [281]	train-auc:0.79192	val-auc:0.76157
# [282]	train-auc:0.79216	val-auc:0.76177
# [283]	train-auc:0.79236	val-auc:0.76184
# [284]	train-auc:0.79240	val-auc:0.76189
# [285]	train-auc:0.79253	val-auc:0.76194
# [286]	train-auc:0.79261	val-auc:0.76201
# [287]	train-auc:0.79278	val-auc:0.76208
# [288]	train-auc:0.79282	val-auc:0.76212
# [289]	train-auc:0.79287	val-auc:0.76216
# [290]	train-auc:0.79296	val-auc:0.76221
# [291]	train-auc:0.79297	val-auc:0.76220
# [292]	train-auc:0.79300	val-auc:0.76220
# [293]	train-auc:0.79306	val-auc:0.76221
# [294]	train-auc:0.79315	val-auc:0.76227
# [295]	train-auc:0.79320	val-auc:0.76229
# [296]	train-auc:0.79346	val-auc:0.76243
# [297]	train-auc:0.79366	val-auc:0.76248
# [298]	train-auc:0.79386	val-auc:0.76251
# [299]	train-auc:0.79407	val-auc:0.76257
# [300]	train-auc:0.79417	val-auc:0.76263
# [301]	train-auc:0.79433	val-auc:0.76267
# [302]	train-auc:0.79448	val-auc:0.76278
# [303]	train-auc:0.79460	val-auc:0.76287
# [304]	train-auc:0.79464	val-auc:0.76289
# [305]	train-auc:0.79470	val-auc:0.76288
# [306]	train-auc:0.79486	val-auc:0.76297
# [307]	train-auc:0.79487	val-auc:0.76298
# [308]	train-auc:0.79502	val-auc:0.76303
# [309]	train-auc:0.79517	val-auc:0.76308
# [310]	train-auc:0.79521	val-auc:0.76309
# [311]	train-auc:0.79525	val-auc:0.76310
# [312]	train-auc:0.79533	val-auc:0.76312
# [313]	train-auc:0.79543	val-auc:0.76320
# [314]	train-auc:0.79550	val-auc:0.76322
# [315]	train-auc:0.79558	val-auc:0.76327
# [316]	train-auc:0.79574	val-auc:0.76335
# [317]	train-auc:0.79595	val-auc:0.76338
# [318]	train-auc:0.79608	val-auc:0.76343
# [319]	train-auc:0.79617	val-auc:0.76349
# [320]	train-auc:0.79636	val-auc:0.76349
# [321]	train-auc:0.79639	val-auc:0.76348
# [322]	train-auc:0.79662	val-auc:0.76357
# [323]	train-auc:0.79675	val-auc:0.76368
# [324]	train-auc:0.79692	val-auc:0.76373
# [325]	train-auc:0.79702	val-auc:0.76379
# [326]	train-auc:0.79708	val-auc:0.76378
# [327]	train-auc:0.79729	val-auc:0.76385
# [328]	train-auc:0.79744	val-auc:0.76389
# [329]	train-auc:0.79758	val-auc:0.76391
# [330]	train-auc:0.79773	val-auc:0.76396
# [331]	train-auc:0.79787	val-auc:0.76402
# [332]	train-auc:0.79808	val-auc:0.76412
# [333]	train-auc:0.79823	val-auc:0.76415
# [334]	train-auc:0.79837	val-auc:0.76421
# [335]	train-auc:0.79850	val-auc:0.76427
# [336]	train-auc:0.79857	val-auc:0.76424
# [337]	train-auc:0.79861	val-auc:0.76422
# [338]	train-auc:0.79883	val-auc:0.76434
# [339]	train-auc:0.79900	val-auc:0.76443
# [340]	train-auc:0.79909	val-auc:0.76454
# [341]	train-auc:0.79922	val-auc:0.76456
# [342]	train-auc:0.79937	val-auc:0.76467
# [343]	train-auc:0.79938	val-auc:0.76467
# [344]	train-auc:0.79944	val-auc:0.76466
# [345]	train-auc:0.79950	val-auc:0.76467
# [346]	train-auc:0.79953	val-auc:0.76467
# [347]	train-auc:0.79959	val-auc:0.76474
# [348]	train-auc:0.79976	val-auc:0.76481
# [349]	train-auc:0.79978	val-auc:0.76481
# [350]	train-auc:0.79987	val-auc:0.76482
# [351]	train-auc:0.79997	val-auc:0.76483
# [352]	train-auc:0.80007	val-auc:0.76487
# [353]	train-auc:0.80028	val-auc:0.76495
# [354]	train-auc:0.80041	val-auc:0.76500
# [355]	train-auc:0.80053	val-auc:0.76508
# [356]	train-auc:0.80066	val-auc:0.76515
# [357]	train-auc:0.80076	val-auc:0.76527
# [358]	train-auc:0.80096	val-auc:0.76541
# [359]	train-auc:0.80114	val-auc:0.76544
# [360]	train-auc:0.80119	val-auc:0.76546
# [361]	train-auc:0.80137	val-auc:0.76554
# [362]	train-auc:0.80156	val-auc:0.76565
# [363]	train-auc:0.80169	val-auc:0.76567
# [364]	train-auc:0.80182	val-auc:0.76576
# [365]	train-auc:0.80185	val-auc:0.76578
# [366]	train-auc:0.80201	val-auc:0.76580
# [367]	train-auc:0.80206	val-auc:0.76578
# [368]	train-auc:0.80213	val-auc:0.76586
# [369]	train-auc:0.80229	val-auc:0.76604
# [370]	train-auc:0.80242	val-auc:0.76608
# [371]	train-auc:0.80262	val-auc:0.76617
# [372]	train-auc:0.80274	val-auc:0.76621
# [373]	train-auc:0.80277	val-auc:0.76624
# [374]	train-auc:0.80290	val-auc:0.76630
# [375]	train-auc:0.80301	val-auc:0.76635
# [376]	train-auc:0.80319	val-auc:0.76646
# [377]	train-auc:0.80328	val-auc:0.76645
# [378]	train-auc:0.80334	val-auc:0.76644
# [379]	train-auc:0.80343	val-auc:0.76645
# [380]	train-auc:0.80348	val-auc:0.76646
# [381]	train-auc:0.80358	val-auc:0.76650
# [382]	train-auc:0.80374	val-auc:0.76658
# [383]	train-auc:0.80395	val-auc:0.76673
# [384]	train-auc:0.80409	val-auc:0.76674
# [385]	train-auc:0.80418	val-auc:0.76678
# [386]	train-auc:0.80426	val-auc:0.76679
# [387]	train-auc:0.80442	val-auc:0.76688
# [388]	train-auc:0.80455	val-auc:0.76702
# [389]	train-auc:0.80466	val-auc:0.76708
# [390]	train-auc:0.80478	val-auc:0.76713
# [391]	train-auc:0.80489	val-auc:0.76718
# [392]	train-auc:0.80500	val-auc:0.76724
# [393]	train-auc:0.80519	val-auc:0.76735
# [394]	train-auc:0.80530	val-auc:0.76737
# [395]	train-auc:0.80542	val-auc:0.76741
# [396]	train-auc:0.80550	val-auc:0.76743
# [397]	train-auc:0.80561	val-auc:0.76745
# [398]	train-auc:0.80563	val-auc:0.76747
# [399]	train-auc:0.80569	val-auc:0.76746
# [400]	train-auc:0.80579	val-auc:0.76751
# [401]	train-auc:0.80593	val-auc:0.76761
# [402]	train-auc:0.80601	val-auc:0.76766
# [403]	train-auc:0.80606	val-auc:0.76770
# [404]	train-auc:0.80625	val-auc:0.76782
# [405]	train-auc:0.80635	val-auc:0.76781
# [406]	train-auc:0.80639	val-auc:0.76784
# [407]	train-auc:0.80643	val-auc:0.76785
# [408]	train-auc:0.80644	val-auc:0.76787
# [409]	train-auc:0.80660	val-auc:0.76799
# [410]	train-auc:0.80668	val-auc:0.76804
# [411]	train-auc:0.80677	val-auc:0.76806
# [412]	train-auc:0.80687	val-auc:0.76806
# [413]	train-auc:0.80692	val-auc:0.76811
# [414]	train-auc:0.80702	val-auc:0.76813
# [415]	train-auc:0.80706	val-auc:0.76813
# [416]	train-auc:0.80711	val-auc:0.76817
# [417]	train-auc:0.80714	val-auc:0.76816
# [418]	train-auc:0.80716	val-auc:0.76817
# [419]	train-auc:0.80722	val-auc:0.76816
# [420]	train-auc:0.80730	val-auc:0.76819
# [421]	train-auc:0.80752	val-auc:0.76832
# [422]	train-auc:0.80764	val-auc:0.76835
# [423]	train-auc:0.80775	val-auc:0.76844
# [424]	train-auc:0.80785	val-auc:0.76848
# [425]	train-auc:0.80794	val-auc:0.76852
# [426]	train-auc:0.80808	val-auc:0.76863
# [427]	train-auc:0.80809	val-auc:0.76862
# [428]	train-auc:0.80813	val-auc:0.76862
# [429]	train-auc:0.80816	val-auc:0.76865
# [430]	train-auc:0.80823	val-auc:0.76870
# [431]	train-auc:0.80827	val-auc:0.76871
# [432]	train-auc:0.80836	val-auc:0.76874
# [433]	train-auc:0.80847	val-auc:0.76881
# [434]	train-auc:0.80853	val-auc:0.76883
# [435]	train-auc:0.80866	val-auc:0.76892
# [436]	train-auc:0.80883	val-auc:0.76895
# [437]	train-auc:0.80898	val-auc:0.76906
# [438]	train-auc:0.80903	val-auc:0.76912
# [439]	train-auc:0.80912	val-auc:0.76915
# [440]	train-auc:0.80914	val-auc:0.76915
# [441]	train-auc:0.80926	val-auc:0.76919
# [442]	train-auc:0.80938	val-auc:0.76926
# [443]	train-auc:0.80940	val-auc:0.76927
# [444]	train-auc:0.80945	val-auc:0.76930
# [445]	train-auc:0.80952	val-auc:0.76935
# [446]	train-auc:0.80956	val-auc:0.76933
# [447]	train-auc:0.80957	val-auc:0.76932
# [448]	train-auc:0.80965	val-auc:0.76936
# [449]	train-auc:0.80981	val-auc:0.76940
# [450]	train-auc:0.80993	val-auc:0.76946
# [451]	train-auc:0.80997	val-auc:0.76946
# [452]	train-auc:0.81005	val-auc:0.76948
# [453]	train-auc:0.81011	val-auc:0.76953
# [454]	train-auc:0.81022	val-auc:0.76955
# [455]	train-auc:0.81024	val-auc:0.76956
# [456]	train-auc:0.81038	val-auc:0.76962
# [457]	train-auc:0.81048	val-auc:0.76964
# [458]	train-auc:0.81056	val-auc:0.76964
# [459]	train-auc:0.81064	val-auc:0.76971
# [460]	train-auc:0.81069	val-auc:0.76970
# [461]	train-auc:0.81080	val-auc:0.76978
# [462]	train-auc:0.81090	val-auc:0.76983
# [463]	train-auc:0.81103	val-auc:0.76990
# [464]	train-auc:0.81116	val-auc:0.76994
# [465]	train-auc:0.81125	val-auc:0.76999
# [466]	train-auc:0.81132	val-auc:0.77001
# [467]	train-auc:0.81133	val-auc:0.77001
# [468]	train-auc:0.81142	val-auc:0.77001
# [469]	train-auc:0.81148	val-auc:0.76998
# [470]	train-auc:0.81157	val-auc:0.77001
# [471]	train-auc:0.81159	val-auc:0.77002
# [472]	train-auc:0.81166	val-auc:0.77005
# [473]	train-auc:0.81177	val-auc:0.77007
# [474]	train-auc:0.81187	val-auc:0.77012
# [475]	train-auc:0.81202	val-auc:0.77016
# [476]	train-auc:0.81210	val-auc:0.77018
# [477]	train-auc:0.81221	val-auc:0.77021
# [478]	train-auc:0.81236	val-auc:0.77023
# [479]	train-auc:0.81247	val-auc:0.77029
# [480]	train-auc:0.81252	val-auc:0.77029
# [481]	train-auc:0.81265	val-auc:0.77036
# [482]	train-auc:0.81275	val-auc:0.77035
# [483]	train-auc:0.81286	val-auc:0.77041
# [484]	train-auc:0.81295	val-auc:0.77051
# [485]	train-auc:0.81300	val-auc:0.77053
# [486]	train-auc:0.81305	val-auc:0.77056
# [487]	train-auc:0.81309	val-auc:0.77057
# [488]	train-auc:0.81316	val-auc:0.77058
# [489]	train-auc:0.81326	val-auc:0.77063
# [490]	train-auc:0.81340	val-auc:0.77067
# [491]	train-auc:0.81355	val-auc:0.77077
# [492]	train-auc:0.81363	val-auc:0.77076
# [493]	train-auc:0.81366	val-auc:0.77078
# [494]	train-auc:0.81376	val-auc:0.77082
# [495]	train-auc:0.81393	val-auc:0.77086
# [496]	train-auc:0.81400	val-auc:0.77089
# [497]	train-auc:0.81411	val-auc:0.77090
# [498]	train-auc:0.81426	val-auc:0.77098
# [499]	train-auc:0.81430	val-auc:0.77099
# [500]	train-auc:0.81444	val-auc:0.77101
# [501]	train-auc:0.81461	val-auc:0.77112
# [502]	train-auc:0.81469	val-auc:0.77119
# [503]	train-auc:0.81475	val-auc:0.77119
# [504]	train-auc:0.81481	val-auc:0.77122
# [505]	train-auc:0.81497	val-auc:0.77122
# [506]	train-auc:0.81506	val-auc:0.77124
# [507]	train-auc:0.81515	val-auc:0.77127
# [508]	train-auc:0.81526	val-auc:0.77133
# [509]	train-auc:0.81533	val-auc:0.77133
# [510]	train-auc:0.81541	val-auc:0.77135
# [511]	train-auc:0.81555	val-auc:0.77139
# [512]	train-auc:0.81563	val-auc:0.77140
# [513]	train-auc:0.81573	val-auc:0.77145
# [514]	train-auc:0.81579	val-auc:0.77145
# [515]	train-auc:0.81597	val-auc:0.77152
# [516]	train-auc:0.81611	val-auc:0.77161
# [517]	train-auc:0.81621	val-auc:0.77163
# [518]	train-auc:0.81626	val-auc:0.77162
# [519]	train-auc:0.81635	val-auc:0.77169
# [520]	train-auc:0.81636	val-auc:0.77170
# [521]	train-auc:0.81642	val-auc:0.77172
# [522]	train-auc:0.81654	val-auc:0.77177
# [523]	train-auc:0.81665	val-auc:0.77180
# [524]	train-auc:0.81677	val-auc:0.77188
# [525]	train-auc:0.81686	val-auc:0.77193
# [526]	train-auc:0.81697	val-auc:0.77200
# [527]	train-auc:0.81706	val-auc:0.77200
# [528]	train-auc:0.81718	val-auc:0.77207
# [529]	train-auc:0.81728	val-auc:0.77210
# [530]	train-auc:0.81740	val-auc:0.77215
# [531]	train-auc:0.81744	val-auc:0.77214
# [532]	train-auc:0.81761	val-auc:0.77222
# [533]	train-auc:0.81766	val-auc:0.77219
# [534]	train-auc:0.81772	val-auc:0.77222
# [535]	train-auc:0.81786	val-auc:0.77225
# [536]	train-auc:0.81790	val-auc:0.77228
# [537]	train-auc:0.81801	val-auc:0.77234
# [538]	train-auc:0.81805	val-auc:0.77235
# [539]	train-auc:0.81809	val-auc:0.77233
# [540]	train-auc:0.81820	val-auc:0.77235
# [541]	train-auc:0.81823	val-auc:0.77236
# [542]	train-auc:0.81827	val-auc:0.77237
# [543]	train-auc:0.81834	val-auc:0.77240
# [544]	train-auc:0.81847	val-auc:0.77243
# [545]	train-auc:0.81856	val-auc:0.77247
# [546]	train-auc:0.81866	val-auc:0.77254
# [547]	train-auc:0.81878	val-auc:0.77260
# [548]	train-auc:0.81886	val-auc:0.77259
# [549]	train-auc:0.81892	val-auc:0.77263
# [550]	train-auc:0.81899	val-auc:0.77268
# [551]	train-auc:0.81903	val-auc:0.77269
# [552]	train-auc:0.81916	val-auc:0.77279
# [553]	train-auc:0.81924	val-auc:0.77285
# [554]	train-auc:0.81929	val-auc:0.77286
# [555]	train-auc:0.81937	val-auc:0.77288
# [556]	train-auc:0.81941	val-auc:0.77291
# [557]	train-auc:0.81947	val-auc:0.77292
# [558]	train-auc:0.81953	val-auc:0.77291
# [559]	train-auc:0.81960	val-auc:0.77292
# [560]	train-auc:0.81970	val-auc:0.77294
# [561]	train-auc:0.81982	val-auc:0.77301
# [562]	train-auc:0.81985	val-auc:0.77302
# [563]	train-auc:0.81993	val-auc:0.77305
# [564]	train-auc:0.81998	val-auc:0.77305
# [565]	train-auc:0.82001	val-auc:0.77308
# [566]	train-auc:0.82012	val-auc:0.77318
# [567]	train-auc:0.82021	val-auc:0.77323
# [568]	train-auc:0.82023	val-auc:0.77324
# [569]	train-auc:0.82026	val-auc:0.77324
# [570]	train-auc:0.82030	val-auc:0.77323
# [571]	train-auc:0.82048	val-auc:0.77330
# [572]	train-auc:0.82061	val-auc:0.77333
# [573]	train-auc:0.82065	val-auc:0.77334
# [574]	train-auc:0.82070	val-auc:0.77335
# [575]	train-auc:0.82078	val-auc:0.77338
# [576]	train-auc:0.82083	val-auc:0.77339
# [577]	train-auc:0.82091	val-auc:0.77338
# [578]	train-auc:0.82095	val-auc:0.77340
# [579]	train-auc:0.82097	val-auc:0.77342
# [580]	train-auc:0.82105	val-auc:0.77341
# [581]	train-auc:0.82113	val-auc:0.77343
# [582]	train-auc:0.82121	val-auc:0.77345
# [583]	train-auc:0.82129	val-auc:0.77350
# [584]	train-auc:0.82136	val-auc:0.77352
# [585]	train-auc:0.82145	val-auc:0.77350
# [586]	train-auc:0.82153	val-auc:0.77351
# [587]	train-auc:0.82162	val-auc:0.77352
# [588]	train-auc:0.82168	val-auc:0.77353
# [589]	train-auc:0.82176	val-auc:0.77358
# [590]	train-auc:0.82185	val-auc:0.77366
# [591]	train-auc:0.82195	val-auc:0.77372
# [592]	train-auc:0.82207	val-auc:0.77373
# [593]	train-auc:0.82219	val-auc:0.77377
# [594]	train-auc:0.82229	val-auc:0.77380
# [595]	train-auc:0.82245	val-auc:0.77384
# [596]	train-auc:0.82252	val-auc:0.77386
# [597]	train-auc:0.82263	val-auc:0.77389
# [598]	train-auc:0.82270	val-auc:0.77395
# [599]	train-auc:0.82281	val-auc:0.77398
# [600]	train-auc:0.82294	val-auc:0.77406
# [601]	train-auc:0.82303	val-auc:0.77411
# [602]	train-auc:0.82310	val-auc:0.77411
# [603]	train-auc:0.82319	val-auc:0.77414
# [604]	train-auc:0.82330	val-auc:0.77416
# [605]	train-auc:0.82337	val-auc:0.77419
# [606]	train-auc:0.82346	val-auc:0.77422
# [607]	train-auc:0.82352	val-auc:0.77424
# [608]	train-auc:0.82359	val-auc:0.77425
# [609]	train-auc:0.82363	val-auc:0.77425
# [610]	train-auc:0.82373	val-auc:0.77423
# [611]	train-auc:0.82381	val-auc:0.77424
# [612]	train-auc:0.82388	val-auc:0.77424
# [613]	train-auc:0.82397	val-auc:0.77429
# [614]	train-auc:0.82407	val-auc:0.77430
# [615]	train-auc:0.82415	val-auc:0.77430
# [616]	train-auc:0.82427	val-auc:0.77435
# [617]	train-auc:0.82433	val-auc:0.77434
# [618]	train-auc:0.82439	val-auc:0.77437
# [619]	train-auc:0.82448	val-auc:0.77439
# [620]	train-auc:0.82462	val-auc:0.77445
# [621]	train-auc:0.82471	val-auc:0.77451
# [622]	train-auc:0.82478	val-auc:0.77453
# [623]	train-auc:0.82486	val-auc:0.77456
# [624]	train-auc:0.82494	val-auc:0.77457
# [625]	train-auc:0.82502	val-auc:0.77460
# [626]	train-auc:0.82509	val-auc:0.77464
# [627]	train-auc:0.82511	val-auc:0.77468
# [628]	train-auc:0.82513	val-auc:0.77466
# [629]	train-auc:0.82527	val-auc:0.77474
# [630]	train-auc:0.82538	val-auc:0.77484
# [631]	train-auc:0.82551	val-auc:0.77488
# [632]	train-auc:0.82563	val-auc:0.77485
# [633]	train-auc:0.82570	val-auc:0.77487
# [634]	train-auc:0.82577	val-auc:0.77490
# [635]	train-auc:0.82589	val-auc:0.77488
# [636]	train-auc:0.82597	val-auc:0.77490
# [637]	train-auc:0.82611	val-auc:0.77497
# [638]	train-auc:0.82623	val-auc:0.77501
# [639]	train-auc:0.82635	val-auc:0.77508
# [640]	train-auc:0.82643	val-auc:0.77511
# [641]	train-auc:0.82647	val-auc:0.77515
# [642]	train-auc:0.82652	val-auc:0.77515
# [643]	train-auc:0.82665	val-auc:0.77522
# [644]	train-auc:0.82670	val-auc:0.77527
# [645]	train-auc:0.82676	val-auc:0.77530
# [646]	train-auc:0.82686	val-auc:0.77530
# [647]	train-auc:0.82699	val-auc:0.77539
# [648]	train-auc:0.82714	val-auc:0.77547
# [649]	train-auc:0.82724	val-auc:0.77551
# [650]	train-auc:0.82729	val-auc:0.77550
# [651]	train-auc:0.82736	val-auc:0.77554
# [652]	train-auc:0.82744	val-auc:0.77558
# [653]	train-auc:0.82751	val-auc:0.77560
# [654]	train-auc:0.82756	val-auc:0.77560
# [655]	train-auc:0.82766	val-auc:0.77562
# [656]	train-auc:0.82775	val-auc:0.77566
# [657]	train-auc:0.82783	val-auc:0.77566
# [658]	train-auc:0.82789	val-auc:0.77566
# [659]	train-auc:0.82795	val-auc:0.77567
# [660]	train-auc:0.82806	val-auc:0.77571
# [661]	train-auc:0.82815	val-auc:0.77575
# [662]	train-auc:0.82825	val-auc:0.77580
# [663]	train-auc:0.82831	val-auc:0.77587
# [664]	train-auc:0.82841	val-auc:0.77590
# [665]	train-auc:0.82850	val-auc:0.77589
# [666]	train-auc:0.82861	val-auc:0.77593
# [667]	train-auc:0.82869	val-auc:0.77597
# [668]	train-auc:0.82870	val-auc:0.77597
# [669]	train-auc:0.82881	val-auc:0.77599
# [670]	train-auc:0.82887	val-auc:0.77599
# [671]	train-auc:0.82895	val-auc:0.77597
# [672]	train-auc:0.82907	val-auc:0.77600
# [673]	train-auc:0.82914	val-auc:0.77602
# [674]	train-auc:0.82925	val-auc:0.77605
# [675]	train-auc:0.82930	val-auc:0.77607
# [676]	train-auc:0.82934	val-auc:0.77607
# [677]	train-auc:0.82939	val-auc:0.77610
# [678]	train-auc:0.82943	val-auc:0.77612
# [679]	train-auc:0.82947	val-auc:0.77613
# [680]	train-auc:0.82948	val-auc:0.77614
# [681]	train-auc:0.82949	val-auc:0.77613
# [682]	train-auc:0.82952	val-auc:0.77613
# [683]	train-auc:0.82956	val-auc:0.77609
# [684]	train-auc:0.82964	val-auc:0.77610
# [685]	train-auc:0.82971	val-auc:0.77610
# [686]	train-auc:0.82975	val-auc:0.77612
# [687]	train-auc:0.82981	val-auc:0.77614
# [688]	train-auc:0.82987	val-auc:0.77616
# [689]	train-auc:0.82993	val-auc:0.77616
# [690]	train-auc:0.83002	val-auc:0.77617
# [691]	train-auc:0.83009	val-auc:0.77618
# [692]	train-auc:0.83013	val-auc:0.77620
# [693]	train-auc:0.83020	val-auc:0.77617
# [694]	train-auc:0.83026	val-auc:0.77621
# [695]	train-auc:0.83031	val-auc:0.77622
# [696]	train-auc:0.83036	val-auc:0.77622
# [697]	train-auc:0.83046	val-auc:0.77626
# [698]	train-auc:0.83052	val-auc:0.77627
# [699]	train-auc:0.83060	val-auc:0.77630
# [700]	train-auc:0.83063	val-auc:0.77630
# [701]	train-auc:0.83072	val-auc:0.77633
# [702]	train-auc:0.83073	val-auc:0.77632
# [703]	train-auc:0.83079	val-auc:0.77635
# [704]	train-auc:0.83087	val-auc:0.77638
# [705]	train-auc:0.83091	val-auc:0.77639
# [706]	train-auc:0.83103	val-auc:0.77641
# [707]	train-auc:0.83110	val-auc:0.77645
# [708]	train-auc:0.83118	val-auc:0.77646
# [709]	train-auc:0.83129	val-auc:0.77654
# [710]	train-auc:0.83141	val-auc:0.77667
# [711]	train-auc:0.83147	val-auc:0.77667
# [712]	train-auc:0.83156	val-auc:0.77667
# [713]	train-auc:0.83161	val-auc:0.77668
# [714]	train-auc:0.83171	val-auc:0.77674
# [715]	train-auc:0.83182	val-auc:0.77675
# [716]	train-auc:0.83193	val-auc:0.77676
# [717]	train-auc:0.83201	val-auc:0.77675
# [718]	train-auc:0.83211	val-auc:0.77680
# [719]	train-auc:0.83218	val-auc:0.77683
# [720]	train-auc:0.83225	val-auc:0.77686
# [721]	train-auc:0.83231	val-auc:0.77691
# [722]	train-auc:0.83241	val-auc:0.77693
# [723]	train-auc:0.83247	val-auc:0.77693
# [724]	train-auc:0.83249	val-auc:0.77693
# [725]	train-auc:0.83254	val-auc:0.77694
# [726]	train-auc:0.83261	val-auc:0.77697
# [727]	train-auc:0.83264	val-auc:0.77698
# [728]	train-auc:0.83267	val-auc:0.77698
# [729]	train-auc:0.83273	val-auc:0.77703
# [730]	train-auc:0.83279	val-auc:0.77707
# [731]	train-auc:0.83284	val-auc:0.77712
# [732]	train-auc:0.83288	val-auc:0.77711
# [733]	train-auc:0.83293	val-auc:0.77711
# [734]	train-auc:0.83303	val-auc:0.77714
# [735]	train-auc:0.83308	val-auc:0.77711
# [736]	train-auc:0.83317	val-auc:0.77711
# [737]	train-auc:0.83322	val-auc:0.77712
# [738]	train-auc:0.83329	val-auc:0.77716
# [739]	train-auc:0.83337	val-auc:0.77718
# [740]	train-auc:0.83343	val-auc:0.77716
# [741]	train-auc:0.83351	val-auc:0.77722
# [742]	train-auc:0.83364	val-auc:0.77726
# [743]	train-auc:0.83365	val-auc:0.77725
# [744]	train-auc:0.83370	val-auc:0.77726
# [745]	train-auc:0.83377	val-auc:0.77730
# [746]	train-auc:0.83386	val-auc:0.77735
# [747]	train-auc:0.83392	val-auc:0.77738
# [748]	train-auc:0.83401	val-auc:0.77737
# [749]	train-auc:0.83411	val-auc:0.77742
# [750]	train-auc:0.83416	val-auc:0.77743
# [751]	train-auc:0.83421	val-auc:0.77743
# [752]	train-auc:0.83426	val-auc:0.77745
# [753]	train-auc:0.83431	val-auc:0.77747
# [754]	train-auc:0.83436	val-auc:0.77749
# [755]	train-auc:0.83439	val-auc:0.77748
# [756]	train-auc:0.83445	val-auc:0.77751
# [757]	train-auc:0.83455	val-auc:0.77759
# [758]	train-auc:0.83461	val-auc:0.77754
# [759]	train-auc:0.83468	val-auc:0.77757
# [760]	train-auc:0.83472	val-auc:0.77757
# [761]	train-auc:0.83473	val-auc:0.77757
# [762]	train-auc:0.83477	val-auc:0.77757
# [763]	train-auc:0.83487	val-auc:0.77757
# [764]	train-auc:0.83493	val-auc:0.77754
# [765]	train-auc:0.83499	val-auc:0.77758
# [766]	train-auc:0.83504	val-auc:0.77758
# [767]	train-auc:0.83509	val-auc:0.77761
# [768]	train-auc:0.83517	val-auc:0.77761
# [769]	train-auc:0.83527	val-auc:0.77768
# [770]	train-auc:0.83539	val-auc:0.77773
# [771]	train-auc:0.83548	val-auc:0.77778
# [772]	train-auc:0.83552	val-auc:0.77781
# [773]	train-auc:0.83559	val-auc:0.77783
# [774]	train-auc:0.83562	val-auc:0.77785
# [775]	train-auc:0.83563	val-auc:0.77786
# [776]	train-auc:0.83567	val-auc:0.77786
# [777]	train-auc:0.83577	val-auc:0.77787
# [778]	train-auc:0.83588	val-auc:0.77790
# [779]	train-auc:0.83596	val-auc:0.77795
# [780]	train-auc:0.83598	val-auc:0.77796
# [781]	train-auc:0.83600	val-auc:0.77795
# [782]	train-auc:0.83601	val-auc:0.77795
# [783]	train-auc:0.83604	val-auc:0.77795
# [784]	train-auc:0.83606	val-auc:0.77795
# [785]	train-auc:0.83614	val-auc:0.77800
# [786]	train-auc:0.83624	val-auc:0.77800
# [787]	train-auc:0.83631	val-auc:0.77801
# [788]	train-auc:0.83638	val-auc:0.77803
# [789]	train-auc:0.83648	val-auc:0.77808
# [790]	train-auc:0.83652	val-auc:0.77810
# [791]	train-auc:0.83660	val-auc:0.77810
# [792]	train-auc:0.83667	val-auc:0.77812
# [793]	train-auc:0.83675	val-auc:0.77813
# [794]	train-auc:0.83685	val-auc:0.77817
# [795]	train-auc:0.83689	val-auc:0.77819
# [796]	train-auc:0.83703	val-auc:0.77821
# [797]	train-auc:0.83710	val-auc:0.77820
# [798]	train-auc:0.83716	val-auc:0.77821
# [799]	train-auc:0.83724	val-auc:0.77824
# [800]	train-auc:0.83732	val-auc:0.77828
# [801]	train-auc:0.83742	val-auc:0.77829
# [802]	train-auc:0.83748	val-auc:0.77831
# [803]	train-auc:0.83755	val-auc:0.77835
# [804]	train-auc:0.83762	val-auc:0.77835
# [805]	train-auc:0.83771	val-auc:0.77839
# [806]	train-auc:0.83780	val-auc:0.77845
# [807]	train-auc:0.83787	val-auc:0.77847
# [808]	train-auc:0.83789	val-auc:0.77847
# [809]	train-auc:0.83796	val-auc:0.77852
# [810]	train-auc:0.83799	val-auc:0.77852
# [811]	train-auc:0.83807	val-auc:0.77854
# [812]	train-auc:0.83811	val-auc:0.77853
# [813]	train-auc:0.83821	val-auc:0.77856
# [814]	train-auc:0.83826	val-auc:0.77858
# [815]	train-auc:0.83830	val-auc:0.77858
# [816]	train-auc:0.83835	val-auc:0.77861
# [817]	train-auc:0.83837	val-auc:0.77861
# [818]	train-auc:0.83841	val-auc:0.77864
# [819]	train-auc:0.83847	val-auc:0.77864
# [820]	train-auc:0.83852	val-auc:0.77860
# [821]	train-auc:0.83858	val-auc:0.77863
# [822]	train-auc:0.83866	val-auc:0.77862
# [823]	train-auc:0.83871	val-auc:0.77863
# [824]	train-auc:0.83880	val-auc:0.77866
# [825]	train-auc:0.83885	val-auc:0.77869
# [826]	train-auc:0.83891	val-auc:0.77868
# [827]	train-auc:0.83900	val-auc:0.77872
# [828]	train-auc:0.83904	val-auc:0.77874
# [829]	train-auc:0.83911	val-auc:0.77876
# [830]	train-auc:0.83919	val-auc:0.77879
# [831]	train-auc:0.83926	val-auc:0.77880
# [832]	train-auc:0.83935	val-auc:0.77885
# [833]	train-auc:0.83940	val-auc:0.77886
# [834]	train-auc:0.83944	val-auc:0.77888
# [835]	train-auc:0.83951	val-auc:0.77889
# [836]	train-auc:0.83957	val-auc:0.77889
# [837]	train-auc:0.83960	val-auc:0.77889
# [838]	train-auc:0.83963	val-auc:0.77888
# [839]	train-auc:0.83964	val-auc:0.77887
# [840]	train-auc:0.83966	val-auc:0.77887
# [841]	train-auc:0.83969	val-auc:0.77891
# [842]	train-auc:0.83973	val-auc:0.77889
# [843]	train-auc:0.83980	val-auc:0.77894
# [844]	train-auc:0.83989	val-auc:0.77897
# [845]	train-auc:0.83992	val-auc:0.77899
# [846]	train-auc:0.84005	val-auc:0.77904
# [847]	train-auc:0.84009	val-auc:0.77904
# [848]	train-auc:0.84017	val-auc:0.77905
# [849]	train-auc:0.84025	val-auc:0.77907
# [850]	train-auc:0.84036	val-auc:0.77911
# [851]	train-auc:0.84045	val-auc:0.77916
# [852]	train-auc:0.84051	val-auc:0.77915
# [853]	train-auc:0.84055	val-auc:0.77917
# [854]	train-auc:0.84061	val-auc:0.77919
# [855]	train-auc:0.84071	val-auc:0.77927
# [856]	train-auc:0.84080	val-auc:0.77932
# [857]	train-auc:0.84085	val-auc:0.77935
# [858]	train-auc:0.84090	val-auc:0.77934
# [859]	train-auc:0.84096	val-auc:0.77937
# [860]	train-auc:0.84103	val-auc:0.77941
# [861]	train-auc:0.84106	val-auc:0.77940
# [862]	train-auc:0.84110	val-auc:0.77941
# [863]	train-auc:0.84114	val-auc:0.77942
# [864]	train-auc:0.84121	val-auc:0.77943
# [865]	train-auc:0.84125	val-auc:0.77946
# [866]	train-auc:0.84129	val-auc:0.77948
# [867]	train-auc:0.84135	val-auc:0.77949
# [868]	train-auc:0.84138	val-auc:0.77951
# [869]	train-auc:0.84143	val-auc:0.77952
# [870]	train-auc:0.84146	val-auc:0.77955
# [871]	train-auc:0.84151	val-auc:0.77958
# [872]	train-auc:0.84154	val-auc:0.77960
# [873]	train-auc:0.84158	val-auc:0.77964
# [874]	train-auc:0.84164	val-auc:0.77966
# [875]	train-auc:0.84168	val-auc:0.77971
# [876]	train-auc:0.84175	val-auc:0.77972
# [877]	train-auc:0.84182	val-auc:0.77971
# [878]	train-auc:0.84185	val-auc:0.77969
# [879]	train-auc:0.84198	val-auc:0.77975
# [880]	train-auc:0.84201	val-auc:0.77975
# [881]	train-auc:0.84208	val-auc:0.77975
# [882]	train-auc:0.84215	val-auc:0.77976
# [883]	train-auc:0.84226	val-auc:0.77982
# [884]	train-auc:0.84229	val-auc:0.77986
# [885]	train-auc:0.84237	val-auc:0.77987
# [886]	train-auc:0.84244	val-auc:0.77994
# [887]	train-auc:0.84251	val-auc:0.77998
# [888]	train-auc:0.84262	val-auc:0.77998
# [889]	train-auc:0.84269	val-auc:0.78002
# [890]	train-auc:0.84276	val-auc:0.78003
# [891]	train-auc:0.84283	val-auc:0.78005
# [892]	train-auc:0.84290	val-auc:0.78006
# [893]	train-auc:0.84294	val-auc:0.78008
# [894]	train-auc:0.84297	val-auc:0.78008
# [895]	train-auc:0.84304	val-auc:0.78012
# [896]	train-auc:0.84312	val-auc:0.78011
# [897]	train-auc:0.84319	val-auc:0.78014
# [898]	train-auc:0.84330	val-auc:0.78020
# [899]	train-auc:0.84337	val-auc:0.78021
# [900]	train-auc:0.84342	val-auc:0.78022
# [901]	train-auc:0.84348	val-auc:0.78022
# [902]	train-auc:0.84357	val-auc:0.78023
# [903]	train-auc:0.84360	val-auc:0.78023
# [904]	train-auc:0.84365	val-auc:0.78024
# [905]	train-auc:0.84372	val-auc:0.78029
# [906]	train-auc:0.84378	val-auc:0.78035
# [907]	train-auc:0.84385	val-auc:0.78038
# [908]	train-auc:0.84393	val-auc:0.78036
# [909]	train-auc:0.84396	val-auc:0.78036
# [910]	train-auc:0.84401	val-auc:0.78034
# [911]	train-auc:0.84405	val-auc:0.78032
# [912]	train-auc:0.84408	val-auc:0.78031
# [913]	train-auc:0.84411	val-auc:0.78031
# [914]	train-auc:0.84421	val-auc:0.78036
# [915]	train-auc:0.84428	val-auc:0.78039
# [916]	train-auc:0.84433	val-auc:0.78039
# [917]	train-auc:0.84440	val-auc:0.78038
# [918]	train-auc:0.84449	val-auc:0.78043
# [919]	train-auc:0.84460	val-auc:0.78045
# [920]	train-auc:0.84469	val-auc:0.78044
# [921]	train-auc:0.84474	val-auc:0.78047
# [922]	train-auc:0.84479	val-auc:0.78049
# [923]	train-auc:0.84484	val-auc:0.78049
# [924]	train-auc:0.84487	val-auc:0.78050
# [925]	train-auc:0.84492	val-auc:0.78051
# [926]	train-auc:0.84496	val-auc:0.78052
# [927]	train-auc:0.84496	val-auc:0.78053
# [928]	train-auc:0.84500	val-auc:0.78054
# [929]	train-auc:0.84508	val-auc:0.78061
# [930]	train-auc:0.84515	val-auc:0.78066
# [931]	train-auc:0.84521	val-auc:0.78065
# [932]	train-auc:0.84523	val-auc:0.78066
# [933]	train-auc:0.84525	val-auc:0.78066
# [934]	train-auc:0.84529	val-auc:0.78066
# [935]	train-auc:0.84536	val-auc:0.78071
# [936]	train-auc:0.84543	val-auc:0.78073
# [937]	train-auc:0.84550	val-auc:0.78073
# [938]	train-auc:0.84557	val-auc:0.78076
# [939]	train-auc:0.84564	val-auc:0.78078
# [940]	train-auc:0.84568	val-auc:0.78081
# [941]	train-auc:0.84569	val-auc:0.78080
# [942]	train-auc:0.84580	val-auc:0.78083
# [943]	train-auc:0.84582	val-auc:0.78083
# [944]	train-auc:0.84585	val-auc:0.78085
# [945]	train-auc:0.84587	val-auc:0.78085
# [946]	train-auc:0.84595	val-auc:0.78088
# [947]	train-auc:0.84597	val-auc:0.78089
# [948]	train-auc:0.84600	val-auc:0.78090
# [949]	train-auc:0.84604	val-auc:0.78092
# [950]	train-auc:0.84610	val-auc:0.78095
# [951]	train-auc:0.84613	val-auc:0.78095
# [952]	train-auc:0.84618	val-auc:0.78096
# [953]	train-auc:0.84625	val-auc:0.78096
# [954]	train-auc:0.84631	val-auc:0.78098
# [955]	train-auc:0.84639	val-auc:0.78098
# [956]	train-auc:0.84646	val-auc:0.78097
# [957]	train-auc:0.84651	val-auc:0.78099
# [958]	train-auc:0.84656	val-auc:0.78101
# [959]	train-auc:0.84658	val-auc:0.78101
# [960]	train-auc:0.84660	val-auc:0.78102
# [961]	train-auc:0.84662	val-auc:0.78099
# [962]	train-auc:0.84669	val-auc:0.78103
# [963]	train-auc:0.84678	val-auc:0.78107
# [964]	train-auc:0.84690	val-auc:0.78115
# [965]	train-auc:0.84697	val-auc:0.78121
# [966]	train-auc:0.84706	val-auc:0.78124
# [967]	train-auc:0.84716	val-auc:0.78128
# [968]	train-auc:0.84723	val-auc:0.78130
# [969]	train-auc:0.84734	val-auc:0.78128
# [970]	train-auc:0.84737	val-auc:0.78129
# [971]	train-auc:0.84737	val-auc:0.78128
# [972]	train-auc:0.84740	val-auc:0.78128
# [973]	train-auc:0.84748	val-auc:0.78132
# [974]	train-auc:0.84754	val-auc:0.78131
# [975]	train-auc:0.84762	val-auc:0.78131
# [976]	train-auc:0.84763	val-auc:0.78132
# [977]	train-auc:0.84772	val-auc:0.78132
# [978]	train-auc:0.84777	val-auc:0.78136
# [979]	train-auc:0.84780	val-auc:0.78138
# [980]	train-auc:0.84786	val-auc:0.78139
# [981]	train-auc:0.84793	val-auc:0.78140
# [982]	train-auc:0.84797	val-auc:0.78138
# [983]	train-auc:0.84805	val-auc:0.78134
# [984]	train-auc:0.84812	val-auc:0.78137
# [985]	train-auc:0.84816	val-auc:0.78136
# [986]	train-auc:0.84820	val-auc:0.78136
# [987]	train-auc:0.84823	val-auc:0.78137
# [988]	train-auc:0.84827	val-auc:0.78139
# [989]	train-auc:0.84829	val-auc:0.78140
# [990]	train-auc:0.84836	val-auc:0.78141
# [991]	train-auc:0.84838	val-auc:0.78143
# [992]	train-auc:0.84840	val-auc:0.78142
# [993]	train-auc:0.84849	val-auc:0.78144
# [994]	train-auc:0.84858	val-auc:0.78151
# [995]	train-auc:0.84860	val-auc:0.78152
# [996]	train-auc:0.84865	val-auc:0.78153
# [997]	train-auc:0.84868	val-auc:0.78155
# [998]	train-auc:0.84873	val-auc:0.78156
# [999]	train-auc:0.84879	val-auc:0.78156
# [1000]	train-auc:0.84884	val-auc:0.78157
# [1001]	train-auc:0.84888	val-auc:0.78157
# [1002]	train-auc:0.84897	val-auc:0.78160
# [1003]	train-auc:0.84902	val-auc:0.78161
# [1004]	train-auc:0.84907	val-auc:0.78160
# [1005]	train-auc:0.84913	val-auc:0.78164
# [1006]	train-auc:0.84917	val-auc:0.78164
# [1007]	train-auc:0.84923	val-auc:0.78160
# [1008]	train-auc:0.84926	val-auc:0.78166
# [1009]	train-auc:0.84932	val-auc:0.78164
# [1010]	train-auc:0.84938	val-auc:0.78168
# [1011]	train-auc:0.84944	val-auc:0.78168
# [1012]	train-auc:0.84948	val-auc:0.78167
# [1013]	train-auc:0.84954	val-auc:0.78172
# [1014]	train-auc:0.84963	val-auc:0.78172
# [1015]	train-auc:0.84967	val-auc:0.78173
# [1016]	train-auc:0.84972	val-auc:0.78173
# [1017]	train-auc:0.84980	val-auc:0.78172
# [1018]	train-auc:0.84990	val-auc:0.78176
# [1019]	train-auc:0.84994	val-auc:0.78179
# [1020]	train-auc:0.85001	val-auc:0.78181
# [1021]	train-auc:0.85005	val-auc:0.78185
# [1022]	train-auc:0.85012	val-auc:0.78188
# [1023]	train-auc:0.85018	val-auc:0.78190
# [1024]	train-auc:0.85024	val-auc:0.78191
# [1025]	train-auc:0.85029	val-auc:0.78194
# [1026]	train-auc:0.85034	val-auc:0.78193
# [1027]	train-auc:0.85040	val-auc:0.78196
# [1028]	train-auc:0.85046	val-auc:0.78196
# [1029]	train-auc:0.85049	val-auc:0.78196
# [1030]	train-auc:0.85055	val-auc:0.78199
# [1031]	train-auc:0.85060	val-auc:0.78201
# [1032]	train-auc:0.85063	val-auc:0.78203
# [1033]	train-auc:0.85071	val-auc:0.78209
# [1034]	train-auc:0.85080	val-auc:0.78213
# [1035]	train-auc:0.85086	val-auc:0.78214
# [1036]	train-auc:0.85090	val-auc:0.78214
# [1037]	train-auc:0.85098	val-auc:0.78216
# [1038]	train-auc:0.85103	val-auc:0.78218
# [1039]	train-auc:0.85106	val-auc:0.78219
# [1040]	train-auc:0.85109	val-auc:0.78219
# [1041]	train-auc:0.85115	val-auc:0.78220
# [1042]	train-auc:0.85121	val-auc:0.78220
# [1043]	train-auc:0.85124	val-auc:0.78222
# [1044]	train-auc:0.85129	val-auc:0.78226
# [1045]	train-auc:0.85133	val-auc:0.78227
# [1046]	train-auc:0.85134	val-auc:0.78227
# [1047]	train-auc:0.85137	val-auc:0.78226
# [1048]	train-auc:0.85140	val-auc:0.78228
# [1049]	train-auc:0.85145	val-auc:0.78226
# [1050]	train-auc:0.85149	val-auc:0.78226
# [1051]	train-auc:0.85155	val-auc:0.78224
# [1052]	train-auc:0.85158	val-auc:0.78226
# [1053]	train-auc:0.85162	val-auc:0.78224
# [1054]	train-auc:0.85168	val-auc:0.78229
# [1055]	train-auc:0.85176	val-auc:0.78232
# [1056]	train-auc:0.85178	val-auc:0.78232
# [1057]	train-auc:0.85182	val-auc:0.78235
# [1058]	train-auc:0.85186	val-auc:0.78237
# [1059]	train-auc:0.85193	val-auc:0.78235
# [1060]	train-auc:0.85202	val-auc:0.78234
# [1061]	train-auc:0.85206	val-auc:0.78235
# [1062]	train-auc:0.85212	val-auc:0.78234
# [1063]	train-auc:0.85217	val-auc:0.78237
# [1064]	train-auc:0.85223	val-auc:0.78237
# [1065]	train-auc:0.85231	val-auc:0.78241
# [1066]	train-auc:0.85237	val-auc:0.78242
# [1067]	train-auc:0.85240	val-auc:0.78243
# [1068]	train-auc:0.85243	val-auc:0.78244
# [1069]	train-auc:0.85251	val-auc:0.78243
# [1070]	train-auc:0.85258	val-auc:0.78247
# [1071]	train-auc:0.85263	val-auc:0.78248
# [1072]	train-auc:0.85270	val-auc:0.78253
# [1073]	train-auc:0.85275	val-auc:0.78257
# [1074]	train-auc:0.85281	val-auc:0.78261
# [1075]	train-auc:0.85285	val-auc:0.78260
# [1076]	train-auc:0.85290	val-auc:0.78260
# [1077]	train-auc:0.85295	val-auc:0.78262
# [1078]	train-auc:0.85299	val-auc:0.78262
# [1079]	train-auc:0.85307	val-auc:0.78268
# [1080]	train-auc:0.85312	val-auc:0.78267
# [1081]	train-auc:0.85317	val-auc:0.78266
# [1082]	train-auc:0.85321	val-auc:0.78266
# [1083]	train-auc:0.85325	val-auc:0.78268
# [1084]	train-auc:0.85327	val-auc:0.78269
# [1085]	train-auc:0.85330	val-auc:0.78265
# [1086]	train-auc:0.85334	val-auc:0.78267
# [1087]	train-auc:0.85339	val-auc:0.78267
# [1088]	train-auc:0.85345	val-auc:0.78270
# [1089]	train-auc:0.85354	val-auc:0.78277
# [1090]	train-auc:0.85366	val-auc:0.78279
# [1091]	train-auc:0.85372	val-auc:0.78281
# [1092]	train-auc:0.85379	val-auc:0.78284
# [1093]	train-auc:0.85386	val-auc:0.78288
# [1094]	train-auc:0.85391	val-auc:0.78289
# [1095]	train-auc:0.85400	val-auc:0.78291
# [1096]	train-auc:0.85406	val-auc:0.78294
# [1097]	train-auc:0.85411	val-auc:0.78294
# [1098]	train-auc:0.85415	val-auc:0.78294
# [1099]	train-auc:0.85423	val-auc:0.78298
# [1100]	train-auc:0.85428	val-auc:0.78300
# [1101]	train-auc:0.85436	val-auc:0.78298
# [1102]	train-auc:0.85443	val-auc:0.78301
# [1103]	train-auc:0.85454	val-auc:0.78307
# [1104]	train-auc:0.85460	val-auc:0.78306
# [1105]	train-auc:0.85465	val-auc:0.78305
# [1106]	train-auc:0.85470	val-auc:0.78304
# [1107]	train-auc:0.85478	val-auc:0.78307
# [1108]	train-auc:0.85483	val-auc:0.78309
# [1109]	train-auc:0.85488	val-auc:0.78310
# [1110]	train-auc:0.85495	val-auc:0.78310
# [1111]	train-auc:0.85502	val-auc:0.78312
# [1112]	train-auc:0.85507	val-auc:0.78314
# [1113]	train-auc:0.85510	val-auc:0.78313
# [1114]	train-auc:0.85516	val-auc:0.78315
# [1115]	train-auc:0.85521	val-auc:0.78317
# [1116]	train-auc:0.85526	val-auc:0.78319
# [1117]	train-auc:0.85528	val-auc:0.78321
# [1118]	train-auc:0.85531	val-auc:0.78321
# [1119]	train-auc:0.85533	val-auc:0.78320
# [1120]	train-auc:0.85539	val-auc:0.78322
# [1121]	train-auc:0.85543	val-auc:0.78324
# [1122]	train-auc:0.85550	val-auc:0.78328
# [1123]	train-auc:0.85556	val-auc:0.78331
# [1124]	train-auc:0.85560	val-auc:0.78330
# [1125]	train-auc:0.85567	val-auc:0.78331
# [1126]	train-auc:0.85572	val-auc:0.78332
# [1127]	train-auc:0.85581	val-auc:0.78334
# [1128]	train-auc:0.85587	val-auc:0.78336
# [1129]	train-auc:0.85589	val-auc:0.78337
# [1130]	train-auc:0.85594	val-auc:0.78338
# [1131]	train-auc:0.85596	val-auc:0.78338
# [1132]	train-auc:0.85600	val-auc:0.78337
# [1133]	train-auc:0.85605	val-auc:0.78334
# [1134]	train-auc:0.85613	val-auc:0.78333
# [1135]	train-auc:0.85618	val-auc:0.78336
# [1136]	train-auc:0.85622	val-auc:0.78336
# [1137]	train-auc:0.85625	val-auc:0.78335
# [1138]	train-auc:0.85629	val-auc:0.78337
# [1139]	train-auc:0.85633	val-auc:0.78334
# [1140]	train-auc:0.85637	val-auc:0.78336
# [1141]	train-auc:0.85639	val-auc:0.78336
# [1142]	train-auc:0.85645	val-auc:0.78339
# [1143]	train-auc:0.85650	val-auc:0.78336
# [1144]	train-auc:0.85654	val-auc:0.78335
# [1145]	train-auc:0.85656	val-auc:0.78337
# [1146]	train-auc:0.85666	val-auc:0.78336
# [1147]	train-auc:0.85673	val-auc:0.78336
# [1148]	train-auc:0.85677	val-auc:0.78336
# [1149]	train-auc:0.85682	val-auc:0.78337
# [1150]	train-auc:0.85688	val-auc:0.78338
# [1151]	train-auc:0.85693	val-auc:0.78335
# [1152]	train-auc:0.85698	val-auc:0.78336
# [1153]	train-auc:0.85704	val-auc:0.78340
# [1154]	train-auc:0.85710	val-auc:0.78344
# [1155]	train-auc:0.85715	val-auc:0.78344
# [1156]	train-auc:0.85721	val-auc:0.78346
# [1157]	train-auc:0.85726	val-auc:0.78346
# [1158]	train-auc:0.85729	val-auc:0.78348
# [1159]	train-auc:0.85733	val-auc:0.78348
# [1160]	train-auc:0.85736	val-auc:0.78350
# [1161]	train-auc:0.85739	val-auc:0.78350
# [1162]	train-auc:0.85742	val-auc:0.78350
# [1163]	train-auc:0.85749	val-auc:0.78352
# [1164]	train-auc:0.85751	val-auc:0.78352
# [1165]	train-auc:0.85754	val-auc:0.78352
# [1166]	train-auc:0.85756	val-auc:0.78353
# [1167]	train-auc:0.85757	val-auc:0.78353
# [1168]	train-auc:0.85760	val-auc:0.78354
# [1169]	train-auc:0.85760	val-auc:0.78354
# [1170]	train-auc:0.85761	val-auc:0.78355
# [1171]	train-auc:0.85766	val-auc:0.78355
# [1172]	train-auc:0.85768	val-auc:0.78355
# [1173]	train-auc:0.85773	val-auc:0.78358
# [1174]	train-auc:0.85778	val-auc:0.78359
# [1175]	train-auc:0.85785	val-auc:0.78360
# [1176]	train-auc:0.85789	val-auc:0.78362
# [1177]	train-auc:0.85791	val-auc:0.78363
# [1178]	train-auc:0.85798	val-auc:0.78364
# [1179]	train-auc:0.85802	val-auc:0.78364
# [1180]	train-auc:0.85805	val-auc:0.78365
# [1181]	train-auc:0.85805	val-auc:0.78366
# [1182]	train-auc:0.85807	val-auc:0.78366
# [1183]	train-auc:0.85815	val-auc:0.78370
# [1184]	train-auc:0.85818	val-auc:0.78370
# [1185]	train-auc:0.85819	val-auc:0.78371
# [1186]	train-auc:0.85820	val-auc:0.78371
# [1187]	train-auc:0.85822	val-auc:0.78370
# [1188]	train-auc:0.85826	val-auc:0.78373
# [1189]	train-auc:0.85831	val-auc:0.78374
# [1190]	train-auc:0.85837	val-auc:0.78375
# [1191]	train-auc:0.85842	val-auc:0.78375
# [1192]	train-auc:0.85846	val-auc:0.78374
# [1193]	train-auc:0.85850	val-auc:0.78377
# [1194]	train-auc:0.85854	val-auc:0.78380
# [1195]	train-auc:0.85855	val-auc:0.78381
# [1196]	train-auc:0.85857	val-auc:0.78382
# ...
# [1462]	train-auc:0.86965	val-auc:0.78667
# [1463]	train-auc:0.86969	val-auc:0.78668
# [1464]	train-auc:0.86973	val-auc:0.78669
# [1465]	train-auc:0.86977	val-auc:0.78669
# [1466]	train-auc:0.86980	val-auc:0.78667
# [1467]	train-auc:0.86983	val-auc:0.78667
# [1468]	train-auc:0.86990	val-auc:0.78672
# [1469]	train-auc:0.86994	val-auc:0.78675
# [1470]	train-auc:0.86997	val-auc:0.78678
# [1471]	train-auc:0.87003	val-auc:0.78677
# [1472]	train-auc:0.87005	val-auc:0.78676
# [1473]	train-auc:0.87011	val-auc:0.78678
# [1474]	train-auc:0.87012	val-auc:0.78675
# [1475]	train-auc:0.87015	val-auc:0.78676
# [1476]	train-auc:0.87016	val-auc:0.78675
# [1477]	train-auc:0.87018	val-auc:0.78678
# [1478]	train-auc:0.87025	val-auc:0.78677
# [1479]	train-auc:0.87026	val-auc:0.78677
# [1480]	train-auc:0.87028	val-auc:0.78677
# [1481]	train-auc:0.87032	val-auc:0.78677
# [1482]	train-auc:0.87033	val-auc:0.78676
# [1483]	train-auc:0.87034	val-auc:0.78677
# [1484]	train-auc:0.87040	val-auc:0.78681
# [1485]	train-auc:0.87046	val-auc:0.78679
# [1486]	train-auc:0.87052	val-auc:0.78680
# [1487]	train-auc:0.87053	val-auc:0.78679
# [1488]	train-auc:0.87058	val-auc:0.78678
# [1489]	train-auc:0.87060	val-auc:0.78680
# [1490]	train-auc:0.87064	val-auc:0.78682
# [1491]	train-auc:0.87069	val-auc:0.78682
# [1492]	train-auc:0.87071	val-auc:0.78683
# [1493]	train-auc:0.87074	val-auc:0.78685
# [1494]	train-auc:0.87078	val-auc:0.78687
# [1495]	train-auc:0.87082	val-auc:0.78684
# [1496]	train-auc:0.87083	val-auc:0.78685
# [1497]	train-auc:0.87089	val-auc:0.78685
# [1498]	train-auc:0.87096	val-auc:0.78686
# [1499]	train-auc:0.87098	val-auc:0.78686
# [1500]	train-auc:0.87100	val-auc:0.78686
# [1501]	train-auc:0.87101	val-auc:0.78687
# [1502]	train-auc:0.87104	val-auc:0.78686
# [1503]	train-auc:0.87107	val-auc:0.78687
# [1504]	train-auc:0.87111	val-auc:0.78689
# [1505]	train-auc:0.87115	val-auc:0.78690
# [1506]	train-auc:0.87117	val-auc:0.78690
# [1507]	train-auc:0.87120	val-auc:0.78689
# [1508]	train-auc:0.87124	val-auc:0.78692
# [1509]	train-auc:0.87128	val-auc:0.78695
# [1510]	train-auc:0.87130	val-auc:0.78694
# [1511]	train-auc:0.87133	val-auc:0.78695
# [1512]	train-auc:0.87135	val-auc:0.78694
# [1513]	train-auc:0.87137	val-auc:0.78694
# [1514]	train-auc:0.87142	val-auc:0.78696
# [1515]	train-auc:0.87146	val-auc:0.78697
# [1516]	train-auc:0.87153	val-auc:0.78702
# [1517]	train-auc:0.87161	val-auc:0.78704
# [1518]	train-auc:0.87164	val-auc:0.78704
# [1519]	train-auc:0.87168	val-auc:0.78706
# [1520]	train-auc:0.87172	val-auc:0.78707
# [1521]	train-auc:0.87176	val-auc:0.78707
# [1522]	train-auc:0.87180	val-auc:0.78709
# [1523]	train-auc:0.87184	val-auc:0.78709
# [1524]	train-auc:0.87189	val-auc:0.78713
# [1525]	train-auc:0.87193	val-auc:0.78716
# [1526]	train-auc:0.87195	val-auc:0.78716
# [1527]	train-auc:0.87199	val-auc:0.78715
# [1528]	train-auc:0.87208	val-auc:0.78715
# [1529]	train-auc:0.87215	val-auc:0.78718
# [1530]	train-auc:0.87218	val-auc:0.78718
# [1531]	train-auc:0.87220	val-auc:0.78719
# [1532]	train-auc:0.87225	val-auc:0.78721
# [1533]	train-auc:0.87229	val-auc:0.78728
# [1534]	train-auc:0.87231	val-auc:0.78728
# [1535]	train-auc:0.87236	val-auc:0.78729
# [1536]	train-auc:0.87241	val-auc:0.78733
# [1537]	train-auc:0.87244	val-auc:0.78734
# [1538]	train-auc:0.87251	val-auc:0.78735
# [1539]	train-auc:0.87255	val-auc:0.78733
# [1540]	train-auc:0.87258	val-auc:0.78734
# [1541]	train-auc:0.87264	val-auc:0.78734
# [1542]	train-auc:0.87267	val-auc:0.78734
# [1543]	train-auc:0.87271	val-auc:0.78735
# [1544]	train-auc:0.87275	val-auc:0.78737
# [1545]	train-auc:0.87276	val-auc:0.78736
# [1546]	train-auc:0.87279	val-auc:0.78738
# [1547]	train-auc:0.87280	val-auc:0.78740
# [1548]	train-auc:0.87282	val-auc:0.78740
# [1549]	train-auc:0.87285	val-auc:0.78738
# [1550]	train-auc:0.87288	val-auc:0.78741
# [1551]	train-auc:0.87290	val-auc:0.78740
# [1552]	train-auc:0.87295	val-auc:0.78741
# [1553]	train-auc:0.87297	val-auc:0.78739
# [1554]	train-auc:0.87300	val-auc:0.78740
# [1555]	train-auc:0.87302	val-auc:0.78740
# [1556]	train-auc:0.87304	val-auc:0.78740
# [1557]	train-auc:0.87309	val-auc:0.78742
# [1558]	train-auc:0.87311	val-auc:0.78741
# [1559]	train-auc:0.87315	val-auc:0.78742
# [1560]	train-auc:0.87316	val-auc:0.78741
# [1561]	train-auc:0.87321	val-auc:0.78743
# [1562]	train-auc:0.87325	val-auc:0.78743
# [1563]	train-auc:0.87331	val-auc:0.78743
# [1564]	train-auc:0.87335	val-auc:0.78745
# [1565]	train-auc:0.87339	val-auc:0.78746
# [1566]	train-auc:0.87345	val-auc:0.78746
# [1567]	train-auc:0.87347	val-auc:0.78745
# [1568]	train-auc:0.87349	val-auc:0.78746
# [1569]	train-auc:0.87352	val-auc:0.78748
# [1570]	train-auc:0.87357	val-auc:0.78747
# [1571]	train-auc:0.87359	val-auc:0.78748
# [1572]	train-auc:0.87359	val-auc:0.78747
# [1573]	train-auc:0.87363	val-auc:0.78748
# [1574]	train-auc:0.87368	val-auc:0.78750
# [1575]	train-auc:0.87369	val-auc:0.78749
# [1576]	train-auc:0.87375	val-auc:0.78750
# [1577]	train-auc:0.87378	val-auc:0.78751
# [1578]	train-auc:0.87383	val-auc:0.78751
# [1579]	train-auc:0.87388	val-auc:0.78751
# [1580]	train-auc:0.87392	val-auc:0.78754
# [1581]	train-auc:0.87394	val-auc:0.78753
# [1582]	train-auc:0.87396	val-auc:0.78753
# [1583]	train-auc:0.87400	val-auc:0.78755
# [1584]	train-auc:0.87403	val-auc:0.78755
# [1585]	train-auc:0.87407	val-auc:0.78758
# [1586]	train-auc:0.87410	val-auc:0.78758
# [1587]	train-auc:0.87414	val-auc:0.78760
# [1588]	train-auc:0.87418	val-auc:0.78761
# [1589]	train-auc:0.87421	val-auc:0.78760
# [1590]	train-auc:0.87426	val-auc:0.78764
# [1591]	train-auc:0.87428	val-auc:0.78762
# [1592]	train-auc:0.87431	val-auc:0.78761
# [1593]	train-auc:0.87433	val-auc:0.78761
# [1594]	train-auc:0.87436	val-auc:0.78760
# [1595]	train-auc:0.87437	val-auc:0.78760
# [1596]	train-auc:0.87440	val-auc:0.78759
# [1597]	train-auc:0.87443	val-auc:0.78760
# [1598]	train-auc:0.87445	val-auc:0.78762
# [1599]	train-auc:0.87449	val-auc:0.78762
# [1600]	train-auc:0.87453	val-auc:0.78763
# [1601]	train-auc:0.87457	val-auc:0.78763
# [1602]	train-auc:0.87461	val-auc:0.78762
# [1603]	train-auc:0.87465	val-auc:0.78763
# [1604]	train-auc:0.87467	val-auc:0.78765
# [1605]	train-auc:0.87469	val-auc:0.78763
# [1606]	train-auc:0.87474	val-auc:0.78767
# [1607]	train-auc:0.87478	val-auc:0.78765
# [1608]	train-auc:0.87483	val-auc:0.78768
# [1609]	train-auc:0.87486	val-auc:0.78769
# [1610]	train-auc:0.87489	val-auc:0.78769
# [1611]	train-auc:0.87491	val-auc:0.78769
# [1612]	train-auc:0.87497	val-auc:0.78772
# [1613]	train-auc:0.87500	val-auc:0.78773
# [1614]	train-auc:0.87504	val-auc:0.78771
# [1615]	train-auc:0.87509	val-auc:0.78773
# [1616]	train-auc:0.87512	val-auc:0.78772
# [1617]	train-auc:0.87513	val-auc:0.78771
# [1618]	train-auc:0.87519	val-auc:0.78774
# [1619]	train-auc:0.87522	val-auc:0.78773
# [1620]	train-auc:0.87527	val-auc:0.78772
# [1621]	train-auc:0.87531	val-auc:0.78771
# [1622]	train-auc:0.87534	val-auc:0.78773
# [1623]	train-auc:0.87538	val-auc:0.78772
# [1624]	train-auc:0.87541	val-auc:0.78771
# [1625]	train-auc:0.87545	val-auc:0.78770
# [1626]	train-auc:0.87549	val-auc:0.78773
# [1627]	train-auc:0.87553	val-auc:0.78772
# [1628]	train-auc:0.87558	val-auc:0.78772
# [1629]	train-auc:0.87560	val-auc:0.78772
# [1630]	train-auc:0.87566	val-auc:0.78773
# [1631]	train-auc:0.87570	val-auc:0.78775
# [1632]	train-auc:0.87575	val-auc:0.78776
# [1633]	train-auc:0.87579	val-auc:0.78779
# [1634]	train-auc:0.87582	val-auc:0.78779
# [1635]	train-auc:0.87586	val-auc:0.78781
# [1636]	train-auc:0.87590	val-auc:0.78780
# [1637]	train-auc:0.87595	val-auc:0.78781
# [1638]	train-auc:0.87599	val-auc:0.78781
# [1639]	train-auc:0.87603	val-auc:0.78781
# [1640]	train-auc:0.87607	val-auc:0.78782
# [1641]	train-auc:0.87608	val-auc:0.78781
# [1642]	train-auc:0.87613	val-auc:0.78785
# [1643]	train-auc:0.87619	val-auc:0.78789
# [1644]	train-auc:0.87626	val-auc:0.78792
# [1645]	train-auc:0.87632	val-auc:0.78792
# [1646]	train-auc:0.87636	val-auc:0.78793
# [1647]	train-auc:0.87642	val-auc:0.78792
# [1648]	train-auc:0.87647	val-auc:0.78791
# [1649]	train-auc:0.87651	val-auc:0.78791
# [1650]	train-auc:0.87655	val-auc:0.78792
# [1651]	train-auc:0.87658	val-auc:0.78791
# [1652]	train-auc:0.87660	val-auc:0.78792
# [1653]	train-auc:0.87662	val-auc:0.78792
# [1654]	train-auc:0.87664	val-auc:0.78792
# [1655]	train-auc:0.87667	val-auc:0.78791
# [1656]	train-auc:0.87670	val-auc:0.78791
# [1657]	train-auc:0.87676	val-auc:0.78795
# [1658]	train-auc:0.87678	val-auc:0.78798
# [1659]	train-auc:0.87682	val-auc:0.78799
# [1660]	train-auc:0.87687	val-auc:0.78802
# [1661]	train-auc:0.87691	val-auc:0.78803
# [1662]	train-auc:0.87694	val-auc:0.78805
# [1663]	train-auc:0.87697	val-auc:0.78806
# [1664]	train-auc:0.87703	val-auc:0.78811
# [1665]	train-auc:0.87705	val-auc:0.78811
# [1666]	train-auc:0.87709	val-auc:0.78810
# [1667]	train-auc:0.87713	val-auc:0.78813
# [1668]	train-auc:0.87716	val-auc:0.78814
# [1669]	train-auc:0.87716	val-auc:0.78813
# [1670]	train-auc:0.87719	val-auc:0.78814
# [1671]	train-auc:0.87723	val-auc:0.78814
# [1672]	train-auc:0.87726	val-auc:0.78816
# [1673]	train-auc:0.87732	val-auc:0.78816
# [1674]	train-auc:0.87736	val-auc:0.78815
# [1675]	train-auc:0.87738	val-auc:0.78814
# [1676]	train-auc:0.87741	val-auc:0.78813
# [1677]	train-auc:0.87747	val-auc:0.78816
# [1678]	train-auc:0.87753	val-auc:0.78819
# [1679]	train-auc:0.87756	val-auc:0.78820
# [1680]	train-auc:0.87759	val-auc:0.78820
# [1681]	train-auc:0.87762	val-auc:0.78821
# [1682]	train-auc:0.87767	val-auc:0.78823
# [1683]	train-auc:0.87772	val-auc:0.78826
# [1684]	train-auc:0.87774	val-auc:0.78826
# [1685]	train-auc:0.87777	val-auc:0.78828
# [1686]	train-auc:0.87783	val-auc:0.78830
# [1687]	train-auc:0.87786	val-auc:0.78828
# [1688]	train-auc:0.87789	val-auc:0.78829
# [1689]	train-auc:0.87794	val-auc:0.78830
# [1690]	train-auc:0.87796	val-auc:0.78830
# [1691]	train-auc:0.87797	val-auc:0.78830
# [1692]	train-auc:0.87800	val-auc:0.78829
# [1693]	train-auc:0.87802	val-auc:0.78829
# [1694]	train-auc:0.87807	val-auc:0.78827
# [1695]	train-auc:0.87809	val-auc:0.78827
# [1696]	train-auc:0.87813	val-auc:0.78829
# [1697]	train-auc:0.87817	val-auc:0.78829
# [1698]	train-auc:0.87822	val-auc:0.78832
# [1699]	train-auc:0.87827	val-auc:0.78834
# [1700]	train-auc:0.87834	val-auc:0.78834
# [1701]	train-auc:0.87836	val-auc:0.78836
# [1702]	train-auc:0.87838	val-auc:0.78836
# [1703]	train-auc:0.87841	val-auc:0.78837
# [1704]	train-auc:0.87846	val-auc:0.78839
# [1705]	train-auc:0.87852	val-auc:0.78841
# [1706]	train-auc:0.87855	val-auc:0.78838
# [1707]	train-auc:0.87858	val-auc:0.78839
# [1708]	train-auc:0.87860	val-auc:0.78839
# [1709]	train-auc:0.87864	val-auc:0.78840
# [1710]	train-auc:0.87870	val-auc:0.78840
# [1711]	train-auc:0.87872	val-auc:0.78840
# [1712]	train-auc:0.87875	val-auc:0.78843
# [1713]	train-auc:0.87880	val-auc:0.78845
# [1714]	train-auc:0.87883	val-auc:0.78846
# [1715]	train-auc:0.87885	val-auc:0.78846
# [1716]	train-auc:0.87888	val-auc:0.78847
# [1717]	train-auc:0.87894	val-auc:0.78848
# [1718]	train-auc:0.87895	val-auc:0.78849
# [1719]	train-auc:0.87898	val-auc:0.78850
# [1720]	train-auc:0.87900	val-auc:0.78851
# [1721]	train-auc:0.87902	val-auc:0.78852
# [1722]	train-auc:0.87903	val-auc:0.78852
# [1723]	train-auc:0.87905	val-auc:0.78853
# [1724]	train-auc:0.87907	val-auc:0.78854
# [1725]	train-auc:0.87912	val-auc:0.78856
# [1726]	train-auc:0.87913	val-auc:0.78855
# [1727]	train-auc:0.87918	val-auc:0.78857
# [1728]	train-auc:0.87923	val-auc:0.78858
# [1729]	train-auc:0.87925	val-auc:0.78857
# [1730]	train-auc:0.87932	val-auc:0.78859
# [1731]	train-auc:0.87936	val-auc:0.78863
# [1732]	train-auc:0.87941	val-auc:0.78863
# [1733]	train-auc:0.87947	val-auc:0.78863
# [1734]	train-auc:0.87950	val-auc:0.78865
# [1735]	train-auc:0.87954	val-auc:0.78867
# [1736]	train-auc:0.87959	val-auc:0.78869
# [1737]	train-auc:0.87962	val-auc:0.78869
# [1738]	train-auc:0.87963	val-auc:0.78869
# [1739]	train-auc:0.87968	val-auc:0.78869
# [1740]	train-auc:0.87972	val-auc:0.78870
# [1741]	train-auc:0.87973	val-auc:0.78869
# [1742]	train-auc:0.87974	val-auc:0.78870
# [1743]	train-auc:0.87977	val-auc:0.78872
# [1744]	train-auc:0.87980	val-auc:0.78872
# [1745]	train-auc:0.87985	val-auc:0.78869
# [1746]	train-auc:0.87991	val-auc:0.78871
# [1747]	train-auc:0.87995	val-auc:0.78872
# [1748]	train-auc:0.87999	val-auc:0.78873
# [1749]	train-auc:0.88002	val-auc:0.78873
# [1750]	train-auc:0.88006	val-auc:0.78876
# [1751]	train-auc:0.88008	val-auc:0.78878
# [1752]	train-auc:0.88009	val-auc:0.78880
# [1753]	train-auc:0.88011	val-auc:0.78878
# [1754]	train-auc:0.88013	val-auc:0.78878
# [1755]	train-auc:0.88014	val-auc:0.78878
# [1756]	train-auc:0.88018	val-auc:0.78877
# [1757]	train-auc:0.88020	val-auc:0.78878
# [1758]	train-auc:0.88023	val-auc:0.78879
# [1759]	train-auc:0.88026	val-auc:0.78880
# [1760]	train-auc:0.88032	val-auc:0.78880
# [1761]	train-auc:0.88036	val-auc:0.78883
# [1762]	train-auc:0.88039	val-auc:0.78883
# [1763]	train-auc:0.88042	val-auc:0.78882
# [1764]	train-auc:0.88046	val-auc:0.78882
# [1765]	train-auc:0.88048	val-auc:0.78883
# [1766]	train-auc:0.88053	val-auc:0.78884
# [1767]	train-auc:0.88057	val-auc:0.78890
# [1768]	train-auc:0.88061	val-auc:0.78891
# [1769]	train-auc:0.88064	val-auc:0.78891
# [1770]	train-auc:0.88069	val-auc:0.78892
# [1771]	train-auc:0.88071	val-auc:0.78895
# [1772]	train-auc:0.88074	val-auc:0.78893
# [1773]	train-auc:0.88078	val-auc:0.78892
# [1774]	train-auc:0.88079	val-auc:0.78894
# [1775]	train-auc:0.88082	val-auc:0.78893
# [1776]	train-auc:0.88086	val-auc:0.78891
# [1777]	train-auc:0.88088	val-auc:0.78893
# [1778]	train-auc:0.88089	val-auc:0.78893
# [1779]	train-auc:0.88093	val-auc:0.78894
# [1780]	train-auc:0.88097	val-auc:0.78896
# [1781]	train-auc:0.88100	val-auc:0.78896
# [1782]	train-auc:0.88102	val-auc:0.78896
# [1783]	train-auc:0.88107	val-auc:0.78901
# [1784]	train-auc:0.88113	val-auc:0.78904
# [1785]	train-auc:0.88117	val-auc:0.78904
# [1786]	train-auc:0.88117	val-auc:0.78903
# [1787]	train-auc:0.88119	val-auc:0.78903
# [1788]	train-auc:0.88124	val-auc:0.78904
# [1789]	train-auc:0.88126	val-auc:0.78904
# [1790]	train-auc:0.88130	val-auc:0.78908
# [1791]	train-auc:0.88133	val-auc:0.78908
# [1792]	train-auc:0.88135	val-auc:0.78908
# [1793]	train-auc:0.88137	val-auc:0.78908
# [1794]	train-auc:0.88139	val-auc:0.78908
# [1795]	train-auc:0.88141	val-auc:0.78907
# [1796]	train-auc:0.88144	val-auc:0.78907
# [1797]	train-auc:0.88148	val-auc:0.78909
# [1798]	train-auc:0.88152	val-auc:0.78911
# [1799]	train-auc:0.88153	val-auc:0.78910
# [1800]	train-auc:0.88154	val-auc:0.78910
# [1801]	train-auc:0.88158	val-auc:0.78911
# [1802]	train-auc:0.88160	val-auc:0.78912
# [1803]	train-auc:0.88161	val-auc:0.78914
# [1804]	train-auc:0.88164	val-auc:0.78914
# [1805]	train-auc:0.88166	val-auc:0.78914
# [1806]	train-auc:0.88167	val-auc:0.78916
# [1807]	train-auc:0.88171	val-auc:0.78916
# [1808]	train-auc:0.88176	val-auc:0.78916
# [1809]	train-auc:0.88179	val-auc:0.78917
# [1810]	train-auc:0.88182	val-auc:0.78918
# [1811]	train-auc:0.88185	val-auc:0.78920
# [1812]	train-auc:0.88188	val-auc:0.78920
# [1813]	train-auc:0.88191	val-auc:0.78921
# [1814]	train-auc:0.88196	val-auc:0.78921
# [1815]	train-auc:0.88200	val-auc:0.78921
# [1816]	train-auc:0.88204	val-auc:0.78924
# [1817]	train-auc:0.88208	val-auc:0.78926
# [1818]	train-auc:0.88210	val-auc:0.78926
# [1819]	train-auc:0.88215	val-auc:0.78925
# [1820]	train-auc:0.88217	val-auc:0.78924
# [1821]	train-auc:0.88220	val-auc:0.78924
# [1822]	train-auc:0.88223	val-auc:0.78926
# [1823]	train-auc:0.88225	val-auc:0.78926
# [1824]	train-auc:0.88226	val-auc:0.78926
# [1825]	train-auc:0.88230	val-auc:0.78927
# [1826]	train-auc:0.88235	val-auc:0.78931
# [1827]	train-auc:0.88236	val-auc:0.78931
# [1828]	train-auc:0.88238	val-auc:0.78932
# [1829]	train-auc:0.88241	val-auc:0.78933
# [1830]	train-auc:0.88241	val-auc:0.78933
# [1831]	train-auc:0.88242	val-auc:0.78933
# [1832]	train-auc:0.88244	val-auc:0.78934
# [1833]	train-auc:0.88245	val-auc:0.78933
# [1834]	train-auc:0.88247	val-auc:0.78931
# [1835]	train-auc:0.88251	val-auc:0.78930
# [1836]	train-auc:0.88254	val-auc:0.78929
# [1837]	train-auc:0.88256	val-auc:0.78927
# [1838]	train-auc:0.88258	val-auc:0.78927
# [1839]	train-auc:0.88262	val-auc:0.78926
# [1840]	train-auc:0.88267	val-auc:0.78928
# [1841]	train-auc:0.88270	val-auc:0.78927
# [1842]	train-auc:0.88275	val-auc:0.78927
# [1843]	train-auc:0.88277	val-auc:0.78929
# [1844]	train-auc:0.88281	val-auc:0.78930
# [1845]	train-auc:0.88286	val-auc:0.78932
# [1846]	train-auc:0.88291	val-auc:0.78933
# [1847]	train-auc:0.88294	val-auc:0.78932
# [1848]	train-auc:0.88297	val-auc:0.78932
# [1849]	train-auc:0.88303	val-auc:0.78932
# [1850]	train-auc:0.88305	val-auc:0.78931
# [1851]	train-auc:0.88308	val-auc:0.78929

# %% [markdown]
# ||1|2a|2a_basic|2b|2b_basic|3|3_basic|4|4_basic|
# |:-:|:-:|:-:|:-:|:-:|:-:|:-:|:-:|:-:|:-:|
# |eta|0.3|0.3|0.3|0.3|0.3|0.3|0.3|0.3|0.3|
# |early stop|20|20|20|20|20|20|20|20|20|
# |num_rounds|2000|500|500|500|500|500|500|500|500|

# %% [markdown]
# #### 4.3.2. Test XGBoost

# %%
aucs, accs, mccs, f1s, recalls = [], [], [], [], []
for test_features, test_labels in zip(test_features_list, test_labels_list):
    dtest = xgb.DMatrix(test_features)
    y_prob = xgb_model.predict(dtest)
    # y_prob = xgb_model.predict(dtest, iteration_range=(0, xgb_model.best_iteration+1))        # worse result

    threshold = 0.5                             # threshold
    y_pred = (y_prob > threshold).astype(int)   # same as >=

    metrics, recall = cal_metrics(test_labels, y_pred, y_prob)
    print(f"- Average (AUC, ACC, MCC, F1): {sum(metrics)/len(metrics):6f}")

    aucs.append(metrics[0])
    accs.append(metrics[1])
    mccs.append(metrics[2])
    f1s.append(metrics[3])
    recalls.append(recall)

print("Average on 5 test sets: ")
print(f"- AUC: {sum(aucs)/len(aucs):.6f} | ACC: {sum(accs)/len(accs):.6f} | MCC: {sum(mccs)/len(mccs):.6f} | F1:  {sum(f1s)/len(f1s):.6f} | Recall:  {sum(recalls)/len(recalls):.6f}")
# Out:
# Validation Performance:
# - AUC: 0.791462 | ACC: 0.709426 | MCC: 0.426681 | F1:  0.734719 | Recall:  0.804771
# - Average (AUC, ACC, MCC, F1): 0.665572
# Validation Performance:
# - AUC: 0.792309 | ACC: 0.710302 | MCC: 0.428318 | F1:  0.735307 | Recall:  0.804771
# - Average (AUC, ACC, MCC, F1): 0.666559
# Validation Performance:
# - AUC: 0.791372 | ACC: 0.709462 | MCC: 0.426749 | F1:  0.734743 | Recall:  0.804771
# - Average (AUC, ACC, MCC, F1): 0.665582
# Validation Performance:
# - AUC: 0.790133 | ACC: 0.708630 | MCC: 0.425194 | F1:  0.734186 | Recall:  0.804771
# - Average (AUC, ACC, MCC, F1): 0.664536
# Validation Performance:
# - AUC: 0.790185 | ACC: 0.707265 | MCC: 0.422645 | F1:  0.733273 | Recall:  0.804771
# - Average (AUC, ACC, MCC, F1): 0.663342
# Average on 5 test sets:
# - AUC: 0.791092 | ACC: 0.709017 | MCC: 0.425917 | F1:  0.734445 | Recall:  0.804771

# %% [markdown]
# - (2b)if not early stop
# > Validation Performance:
#     - AUC: 0.735394
#     - ACC: 0.659510
#     - MCC: 0.321043
#     - F1:  0.677575
#     - Recall:  0.715539
#     Average (AUC, ACC, MCC, F1): 0.598381
#
# - (2b)if early stop, round=20
# > Validation Performance:
#     - AUC: 0.740468
#     - ACC: 0.665794
#     - MCC: 0.334877
#     - F1:  0.687630
#     - Recall:  0.735698
#     Average (AUC, ACC, MCC, F1): 0.607192
